# %%
import pandas as pd

# %%
url = 'tabla_estaciones.csv'
df = pd.read_csv(url)

# %%
df.head(20)
# Out:
#        id                    name  downhill_skiing  nordic_skiing  status_id  \
# 0   22001                Alp 2500                1              0          1
# 1      20               La Molina                1              0          1
# 2      19                 Masella                1              0          1
# 3      16          Baqueira Beret                1              0          1
# 4      17               Boí Taüll                1              0          1
# 5      18                   Espot                1              0          1
# 6      21               Port Ainé                1              0          1
# 7      22          Port del Comte                1              0          1
# 8    2412                Tavascán                1              0          4
# 9      23           Vall de Nuria                1              0          1
# 10     24                 Vallter                1              0          4
# ...

# %%
df.groupby('name')[['lifts_total', 'runs_total', 'km_total']].mean(numeric_only=True).head(20)
# Out:
#                           lifts_total  runs_total  km_total
# name
# 100K Astún - Candanchú           37.0       100.0    100.50
# Alp 2500                         33.0       145.0    145.00
# Alto Campoo                      12.0        30.0     30.38
# Artouste                         11.0        25.0     25.00
# Ascou-Pailhères                   7.0        17.0     17.00
# Astún                            15.0        50.0     50.00
# Ax 3 Domaines                    19.0        80.0     80.00
# Baqueira Beret                   36.0       170.0    170.00
# Bourg d´Oueil                     3.0         5.0      5.00
# Boí Taüll                        10.0        46.0     46.00
# Cambre d´Aze                     16.0        22.0     22.00
# Camurac                           5.0        15.0     15.00
# Candanchú                        22.0        50.0     50.50
# Cauterets                        15.0        40.0     40.00
# Cauterets Cirque du Lys          11.0        36.0     36.00
# ...
