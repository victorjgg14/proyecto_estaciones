# %%
import requests
import pandas as pd

# %%
url = 'https://www.infonieve.es/datos/api/parte-de-nieve/v2/proy-edu-v1ctorj_dev.json'

requests.get(url)
# Out:
# <Response [200]>

# %%
res = requests.get(url)

res.json()
# Out:
# {'resorts': [{'id': 22001,
#    'name': 'Alp 2500',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '02/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '10/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '19',
#      'lifts_total': '33',
#      'runs_open': '59',
#      'runs_total': '138',
#      'km_open': '71',
#      'km_total': '145',
#      'snowdepth_min': '40',
#      'snowdepth_max': '75',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '18',
#      'green_runs_total': '29',
#      'blue_runs_open': '24',
#      'blue_runs_total': '49',
#      'red_runs_open': '15',
#      'red_runs_total': '44',
#      'black_runs_open': '2',
#      'black_runs_total': '16',
#      'special_runs': 0,
#      'avalanche_risk': '0',
#      'avalanche_risk_text': 'Sin Riesgo',
#      'extended_elements': [{'group_name': 'Dominio',
#        'group_items': [{'element_name': 'Conexión Alp2500',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '31'}]}]},
#     {'date': '2023-01-20',
#      'updated': '2023-01-20 11:24:09',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '12',
#      'lifts_total': '33',
#      'runs_open': '41',
#      'runs_total': '138',
#      'km_open': '40',
#      'km_total': '145',
#      'snowdepth_min': '40',
#      'snowdepth_max': '75',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '19',
#      'green_runs_total': '29',
#      'blue_runs_open': '17',
#      'blue_runs_total': '49',
#      'red_runs_open': '5',
#      'red_runs_total': '44',
#      'black_runs_open': '-',
#      'black_runs_total': '16',
#      'special_runs': 0,
#      'avalanche_risk': '0',
#      'avalanche_risk_text': 'Sin Riesgo',
#      'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#      'extended_elements': [{'group_name': 'Dominio',
#        'group_items': [{'element_name': 'Conexión Alp2500',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': '31'}]}]},
#     {'date': '2023-01-22',
#      'updated': '2023-01-22 10:26:03',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '16',
#      'lifts_total': '33',
#      'runs_open': '44',
#      'runs_total': '138',
#      'km_open': '42',
#      'km_total': '145',
#      'snowdepth_min': '40',
#      'snowdepth_max': '75',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '20',
#      'green_runs_total': '29',
#      'blue_runs_open': '19',
#      'blue_runs_total': '49',
#      'red_runs_open': '5',
#      'red_runs_total': '44',
#      'black_runs_open': '-',
#      'black_runs_total': '16',
#      'special_runs': 0,
#      'avalanche_risk': '0',
#      'avalanche_risk_text': 'Sin Riesgo',
#      'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#      'extended_elements': [{'group_name': 'Dominio',
#        'group_items': [{'element_name': 'Conexión Alp2500',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': '31'}]}]}]},
#   {'id': 20,
#    'name': 'La Molina',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '03/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '10/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 09:17:53',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '8',
#      'lifts_total': '16',
#      'runs_open': '25',
#      'runs_total': '66',
#      'km_open': '22',
#      'km_total': '71',
#      'snowdepth_min': '40',
#      'snowdepth_max': '65',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '11',
#      'green_runs_total': '20',
#      'blue_runs_open': '7',
#      'blue_runs_total': '18',
#      'red_runs_open': '6',
#      'red_runs_total': '22',
#      'black_runs_open': '1',
#      'black_runs_total': '6',
#      'special_runs': 0,
#      'avalanche_risk': '0',
#      'avalanche_risk_text': 'Sin Riesgo',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 30},
#         {'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 67},
#         {'element_name': 'Raquetas',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 33},
#         {'element_name': 'Trineos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 32}]},
#       {'group_name': 'Dominio',
#        'group_items': [{'element_name': 'Conexión Alp2500',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '31'}]}]}]},
#   {'id': 19,
#    'name': 'Masella',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '02/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '10/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '11',
#      'lifts_total': '17',
#      'runs_open': '34',
#      'runs_total': '72',
#      'km_open': '49',
#      'km_total': '74',
#      'snowdepth_min': '40',
#      'snowdepth_max': '75',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '7',
#      'green_runs_total': '9',
#      'blue_runs_open': '17',
#      'blue_runs_total': '31',
#      'red_runs_open': '9',
#      'red_runs_total': '22',
#      'black_runs_open': '1',
#      'black_runs_total': '10',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'extended_elements': [{'group_name': 'Dominio',
#        'group_items': [{'element_name': 'Conexión Alp2500',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '31'}]}]}]},
#   {'id': 16,
#    'name': 'Baqueira Beret',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '26/11/2022',
#    'opening_confirmed': 1,
#    'closing_date': '10/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '30',
#      'lifts_total': '36',
#      'runs_open': '69',
#      'runs_total': '116',
#      'km_open': '110',
#      'km_total': '170',
#      'snowdepth_min': '60',
#      'snowdepth_max': '90',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '5',
#      'green_runs_total': '5',
#      'blue_runs_open': '35',
#      'blue_runs_total': '43',
#      'red_runs_open': '26',
#      'red_runs_total': '48',
#      'black_runs_open': '3',
#      'black_runs_total': '17',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '3',
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Esquí de fondo',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 29}]},
#       {'group_name': 'Sectores',
#        'group_items': [{'element_name': 'Baqueira',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Beret',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Bonaigua',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Baciver',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': '56'}]}]},
#     {'date': '2023-01-20',
#      'updated': '2023-01-20 11:24:09',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '27',
#      'lifts_total': '36',
#      'runs_open': '56',
#      'runs_total': '116',
#      'km_open': '100',
#      'km_total': '170',
#      'snowdepth_min': '90',
#      'snowdepth_max': '130',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '5',
#      'green_runs_total': '5',
#      'blue_runs_open': '28',
#      'blue_runs_total': '43',
#      'red_runs_open': '20',
#      'red_runs_total': '48',
#      'black_runs_open': '3',
#      'black_runs_total': '17',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '3',
#      'avalanche_risk': '4',
#      'avalanche_risk_text': 'Fuerte',
#      'comment': 'Previsión de condiciones meteorológicas adversas. Los datos de apertura podrían verse condicionados en función de la evolución de las condiciones meteorológicas.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Esquí de fondo',
#          'element_status_id': '2',
#          'element_status_text': 'Previsión apertura',
#          'element_icon': 29}]},
#       {'group_name': 'Sectores',
#        'group_items': [{'element_name': 'Baqueira',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Beret',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Bonaigua',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Baciver',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': '56'}]}]}]},
#   {'id': 17,
#    'name': 'Boí Taüll',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '02/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '10/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '6',
#      'lifts_total': '10',
#      'runs_open': '24',
#      'runs_total': '43',
#      'km_open': '26',
#      'km_total': '46',
#      'snowdepth_min': '65',
#      'snowdepth_max': '130',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '6',
#      'green_runs_total': '6',
#      'blue_runs_open': '5',
#      'blue_runs_total': '6',
#      'red_runs_open': '7',
#      'red_runs_total': '15',
#      'black_runs_open': '6',
#      'black_runs_total': '16',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 67,
#          'element_num_open': '2',
#          'element_num_total': '4',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '5.54',
#          'element_km_total': '11.76'},
#         {'element_name': 'Trineos',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 32}]}]}]},
#   {'id': 18,
#    'name': 'Espot',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '02/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '31/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 09:17:53',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '5',
#      'lifts_total': '5',
#      'runs_open': '10',
#      'runs_total': '22',
#      'km_open': '11',
#      'km_total': '25',
#      'snowdepth_min': '50',
#      'snowdepth_max': '80',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '2',
#      'green_runs_total': '2',
#      'blue_runs_open': '4',
#      'blue_runs_total': '10',
#      'red_runs_open': '3',
#      'red_runs_total': '6',
#      'black_runs_open': '1',
#      'black_runs_total': '4',
#      'special_runs': 0,
#      'avalanche_risk': '5',
#      'avalanche_risk_text': 'Extremo',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 67},
#         {'element_name': 'Raquetas',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 33,
#          'element_num_open': '1',
#          'element_num_total': '3',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '0.8',
#          'element_km_total': '5.2'},
#         {'element_name': 'Trineos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 32}]}]}]},
#   {'id': 21,
#    'name': 'Port Ainé',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '02/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '10/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '7',
#      'lifts_total': '7',
#      'runs_open': '21',
#      'runs_total': '25',
#      'km_open': '24',
#      'km_total': '27',
#      'snowdepth_min': '45',
#      'snowdepth_max': '75',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '6',
#      'green_runs_total': '6',
#      'blue_runs_open': '4',
#      'blue_runs_total': '4',
#      'red_runs_open': '8',
#      'red_runs_total': '11',
#      'black_runs_open': '3',
#      'black_runs_total': '4',
#      'special_runs': 0,
#      'avalanche_risk': '2',
#      'avalanche_risk_text': 'Limitado',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 67,
#          'element_num_open': '4',
#          'element_num_total': '4',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '9.66',
#          'element_km_total': '9.66'},
#         {'element_name': 'Raquetas',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 33,
#          'element_num_open': '2',
#          'element_num_total': '3',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '8.64',
#          'element_km_total': '18.01'},
#         {'element_name': 'Trineos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 32}]}]},
#     {'date': '2023-01-20',
#      'updated': '2023-01-20 11:24:09',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '5',
#      'lifts_total': '7',
#      'runs_open': '6',
#      'runs_total': '25',
#      'km_open': '7',
#      'km_total': '27',
#      'snowdepth_min': '45',
#      'snowdepth_max': '75',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '4',
#      'green_runs_total': '6',
#      'blue_runs_open': '-',
#      'blue_runs_total': '4',
#      'red_runs_open': '1',
#      'red_runs_total': '11',
#      'black_runs_open': '1',
#      'black_runs_total': '4',
#      'special_runs': 0,
#      'avalanche_risk': '2',
#      'avalanche_risk_text': 'Limitado',
#      'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 67,
#          'element_num_open': '4',
#          'element_num_total': '4',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '9.66',
#          'element_km_total': '9.66'},
#         {'element_name': 'Raquetas',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 33,
#          'element_num_open': '2',
#          'element_num_total': '3',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '8.64',
#          'element_km_total': '18.01'},
#         {'element_name': 'Trineos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 32}]}]}]},
#   {'id': 22,
#    'name': 'Port del Comte',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '03/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '10/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '5',
#      'lifts_total': '17',
#      'runs_open': '6',
#      'runs_total': '39',
#      'km_open': '6',
#      'km_total': '50',
#      'snowdepth_min': '20',
#      'snowdepth_max': '35',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '5',
#      'green_runs_total': '8',
#      'blue_runs_open': '1',
#      'blue_runs_total': '13',
#      'red_runs_open': '-',
#      'red_runs_total': '12',
#      'black_runs_open': '-',
#      'black_runs_total': '6',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'extended_elements': [{'group_name': 'Sectores',
#        'group_items': [{'element_name': 'Donadó',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Sucre',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': '56'},
#         {'element_name': 'Estivella',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': '56'}]}]}]},
#   {'id': 2412,
#    'name': 'Tavascán',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '07/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '6',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '3',
#      'runs_open': '-',
#      'runs_total': '7',
#      'km_open': '-',
#      'km_total': '7',
#      'snowdepth_min': '60',
#      'snowdepth_max': '90',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '-',
#      'green_runs_total': '2',
#      'blue_runs_open': '-',
#      'blue_runs_total': '1',
#      'red_runs_open': '-',
#      'red_runs_total': '2',
#      'black_runs_open': '-',
#      'black_runs_total': '2',
#      'special_runs': 0,
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'comment': 'Pistas de esquí cerradas. Previsión de reapertura: viernes 20 de enero de 2023.'}]},
#   {'id': 23,
#    'name': 'Vall de Nuria',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '03/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 09:17:53',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '3',
#      'lifts_total': '7',
#      'runs_open': '3',
#      'runs_total': '11',
#      'km_open': '1',
#      'km_total': '8',
#      'snowdepth_min': '30',
#      'snowdepth_max': '50',
#      'snow_quality': 'Polvo/Dura',
#      'green_runs_open': '3',
#      'green_runs_total': '3',
#      'blue_runs_open': '-',
#      'blue_runs_total': '3',
#      'red_runs_open': '-',
#      'red_runs_total': '3',
#      'black_runs_open': '-',
#      'black_runs_total': '2',
#      'special_runs': 0,
#      'avalanche_risk': '0',
#      'avalanche_risk_text': 'Sin Riesgo',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 67,
#          'element_num_open': '1',
#          'element_num_total': '2',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '1.85',
#          'element_km_total': '2.98'},
#         {'element_name': 'Raquetas',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 33,
#          'element_num_open': '1',
#          'element_num_total': '7',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '1.85',
#          'element_km_total': '11.84'},
#         {'element_name': 'Trineos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 32}]}]},
#     {'date': '2023-01-20',
#      'updated': '2023-01-20 08:49:02',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '3',
#      'lifts_total': '7',
#      'runs_open': '3',
#      'runs_total': '11',
#      'km_open': '1',
#      'km_total': '8',
#      'snowdepth_min': '30',
#      'snowdepth_max': '50',
#      'snow_quality': 'Polvo/Dura',
#      'green_runs_open': '3',
#      'green_runs_total': '3',
#      'blue_runs_open': '-',
#      'blue_runs_total': '3',
#      'red_runs_open': '-',
#      'red_runs_total': '3',
#      'black_runs_open': '-',
#      'black_runs_total': '2',
#      'special_runs': 0,
#      'avalanche_risk': '0',
#      'avalanche_risk_text': 'Sin Riesgo',
#      'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 67,
#          'element_num_open': '1',
#          'element_num_total': '2',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '1.85',
#          'element_km_total': '2.98'},
#         {'element_name': 'Raquetas',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 33,
#          'element_num_open': '3',
#          'element_num_total': '7',
#          'element_num_text': 'itinerarios',
#          'element_km_open': '7.65',
#          'element_km_total': '11.84'},
#         {'element_name': 'Trineos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 32}]}]}]},
#   {'id': 24,
#    'name': 'Vallter',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '04/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '22/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 09:17:53',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '3',
#      'lifts_total': '10',
#      'runs_open': '2',
#      'runs_total': '13',
#      'km_open': '1',
#      'km_total': '13',
#      'snowdepth_min': '15',
#      'snowdepth_max': '40',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '2',
#      'green_runs_total': '3',
#      'blue_runs_open': '-',
#      'blue_runs_total': '4',
#      'red_runs_open': '-',
#      'red_runs_total': '6',
#      'black_runs_open': '-',
#      'black_runs_total': '-',
#      'special_runs': 0,
#      'avalanche_risk': '0',
#      'avalanche_risk_text': 'Sin Riesgo',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 67},
#         {'element_name': 'Trineos',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 32}]}]}]},
#   {'id': 22003,
#    'name': '100K Astún - Candanchú',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '03/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '20',
#      'lifts_total': '37',
#      'runs_open': '43',
#      'runs_total': '118',
#      'km_open': '39,5',
#      'km_total': '100,5',
#      'snowdepth_min': '100',
#      'snowdepth_max': '160',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '16',
#      'green_runs_total': '17',
#      'blue_runs_open': '16',
#      'blue_runs_total': '32',
#      'red_runs_open': '10',
#      'red_runs_total': '40',
#      'black_runs_open': '1',
#      'black_runs_total': '19',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '10',
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable'}]},
#   {'id': 7,
#    'name': 'Astún',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '03/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '11',
#      'lifts_total': '15',
#      'runs_open': '24',
#      'runs_total': '61',
#      'km_open': '24',
#      'km_total': '50',
#      'snowdepth_min': '125',
#      'snowdepth_max': '155',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '5',
#      'green_runs_total': '5',
#      'blue_runs_open': '12',
#      'blue_runs_total': '18',
#      'red_runs_open': '7',
#      'red_runs_total': '22',
#      'black_runs_open': '-',
#      'black_runs_total': '6',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '10',
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Trineos',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 32}]}]}]},
#   {'id': 8,
#    'name': 'Candanchú',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '03/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '9',
#      'lifts_total': '22',
#      'runs_open': '19',
#      'runs_total': '57',
#      'km_open': '15,5',
#      'km_total': '50,5',
#      'snowdepth_min': '100',
#      'snowdepth_max': '160',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '11',
#      'green_runs_total': '12',
#      'blue_runs_open': '4',
#      'blue_runs_total': '14',
#      'red_runs_open': '3',
#      'red_runs_total': '18',
#      'black_runs_open': '1',
#      'black_runs_total': '13',
#      'special_runs': 0,
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Trineos',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 32}]}]}]},
#   {'id': 9,
#    'name': 'Cerler',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '06/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '9',
#      'lifts_total': '20',
#      'runs_open': '14',
#      'runs_total': '72',
#      'km_open': '39',
#      'km_total': '80',
#      'snowdepth_min': '35',
#      'snowdepth_max': '75',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '6',
#      'green_runs_total': '10',
#      'blue_runs_open': '8',
#      'blue_runs_total': '19',
#      'red_runs_open': '-',
#      'red_runs_total': '27',
#      'black_runs_open': '-',
#      'black_runs_total': '16',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '1',
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 67},
#         {'element_name': 'Raquetas',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 33}]}]}]},
#   {'id': 22002,
#    'name': 'Formigal - Panticosa',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '03/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '27',
#      'lifts_total': '37',
#      'runs_open': '77',
#      'runs_total': '147',
#      'km_open': '90',
#      'km_total': '182',
#      'snowdepth_min': '30',
#      'snowdepth_max': '170',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '11',
#      'green_runs_total': '12',
#      'blue_runs_open': '25',
#      'blue_runs_total': '36',
#      'red_runs_open': '31',
#      'red_runs_total': '52',
#      'black_runs_open': '10',
#      'black_runs_total': '42',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '5',
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'comment': 'Previsión de condiciones meteorológicas adversas. Los datos de apertura podrían verse condicionados en función de la evolución de las condiciones meteorológicas.'}]},
#   {'id': 10,
#    'name': 'Formigal',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '03/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '19',
#      'lifts_total': '22',
#      'runs_open': '59',
#      'runs_total': '102',
#      'km_open': '73',
#      'km_total': '143',
#      'snowdepth_min': '45',
#      'snowdepth_max': '170',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '5',
#      'green_runs_total': '6',
#      'blue_runs_open': '20',
#      'blue_runs_total': '20',
#      'red_runs_open': '24',
#      'red_runs_total': '35',
#      'black_runs_open': '10',
#      'black_runs_total': '37',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '4',
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'comment': 'Previsión de condiciones meteorológicas adversas. Los datos de apertura podrían verse condicionados en función de la evolución de las condiciones meteorológicas.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': 30}]},
#       {'group_name': 'Valles',
#        'group_items': [{'element_name': 'Sextas - Tres Hombres',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Izas - Sarrios',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Anayet',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Portalet',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'}]}]}]},
#   {'id': 11,
#    'name': 'Panticosa',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '26/12/2022',
#    'opening_confirmed': 1,
#    'closing_date': '09/04/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:52:22',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '8',
#      'lifts_total': '15',
#      'runs_open': '18',
#      'runs_total': '45',
#      'km_open': '17',
#      'km_total': '39',
#      'snowdepth_min': '30',
#      'snowdepth_max': '110',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '6',
#      'green_runs_total': '6',
#      'blue_runs_open': '5',
#      'blue_runs_total': '16',
#      'red_runs_open': '7',
#      'red_runs_total': '17',
#      'black_runs_open': '-',
#      'black_runs_total': '5',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '1',
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones meteorológicas y los trabajos de acondicionamiento de pistas y remontes.',
#      'extended_elements': [{'group_name': 'Valles',
#        'group_items': [{'element_name': 'Petrosos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Sabocos',
#          'element_status_id': '2',
#          'element_status_text': 'Previsión apertura',
#          'element_icon': '56'}]}]},
#     {'date': '2023-01-20',
#      'updated': '2023-01-20 11:24:09',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '10',
#      'lifts_total': '15',
#      'runs_open': '23',
#      'runs_total': '45',
#      'km_open': '18',
#      'km_total': '39',
#      'snowdepth_min': '50',
#      'snowdepth_max': '150',
#      'snow_quality': 'Polvo',
#      'green_runs_open': '6',
#      'green_runs_total': '6',
#      'blue_runs_open': '9',
#      'blue_runs_total': '16',
#      'red_runs_open': '8',
#      'red_runs_total': '17',
#      'black_runs_open': '-',
#      'black_runs_total': '5',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '1',
#      'avalanche_risk': '3',
#      'avalanche_risk_text': 'Notable',
#      'comment': 'Previsión de condiciones meteorológicas adversas. Los datos de apertura podrían verse condicionados en función de la evolución de las condiciones meteorológicas.',
#      'extended_elements': [{'group_name': 'Valles',
#        'group_items': [{'element_name': 'Petrosos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'},
#         {'element_name': 'Sabocos',
#          'element_status_id': '1',
#          'element_status_text': 'Abierto',
#          'element_icon': '56'}]}]}]},
#   {'id': 15,
#    'name': 'Alto Campoo',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '20/01/2023',
#    'opening_confirmed': 1,
#    'closing_date': '28/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 12:03:15',
#      'status_id': '6',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '12',
#      'runs_open': '-',
#      'runs_total': '23',
#      'km_open': '-',
#      'km_total': '30,38',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '4',
#      'blue_runs_open': '-',
#      'blue_runs_total': '10',
#      'red_runs_open': '-',
#      'red_runs_total': '9',
#      'black_runs_open': '-',
#      'black_runs_total': '-',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Viernes 20 de Enero de 2023.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Esquí de fondo',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 29}]}]}]},
#   {'id': 5448,
#    'name': 'Fuentes de Invierno',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '22/01/2023',
#    'opening_confirmed': 1,
#    'closing_date': '23/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:53:53',
#      'status_id': '2',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '5',
#      'runs_open': '-',
#      'runs_total': '15',
#      'km_open': '-',
#      'km_total': '8,76',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '3',
#      'blue_runs_open': '-',
#      'blue_runs_total': '3',
#      'red_runs_open': '-',
#      'red_runs_total': '6',
#      'black_runs_open': '-',
#      'black_runs_total': '3',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información'}]},
#   {'id': 25,
#    'name': 'Manzaneda',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '27/01/2023',
#    'opening_confirmed': 1,
#    'closing_date': '07/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:53:53',
#      'status_id': '6',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '6',
#      'runs_open': '-',
#      'runs_total': '23',
#      'km_open': '-',
#      'km_total': '16,75',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '1',
#      'blue_runs_open': '-',
#      'blue_runs_total': '13',
#      'red_runs_open': '-',
#      'red_runs_total': '8',
#      'black_runs_open': '-',
#      'black_runs_total': '1',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Viernes 20 de Enero de 2023.'}]},
#   {'id': 14,
#    'name': 'San Isidro',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '21/01/2023',
#    'opening_confirmed': 1,
#    'closing_date': '26/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:53:53',
#      'status_id': '2',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '15',
#      'runs_open': '-',
#      'runs_total': '32',
#      'km_open': '-',
#      'km_total': '31,1',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '6',
#      'blue_runs_open': '-',
#      'blue_runs_total': '8',
#      'red_runs_open': '-',
#      'red_runs_total': '13',
#      'black_runs_open': '-',
#      'black_runs_total': '4',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '1',
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Esquí de fondo',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 29}]}]}]},
#   {'id': 13,
#    'name': 'Valgrande-Pajares',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '22/01/2023',
#    'opening_confirmed': 1,
#    'closing_date': '15/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 19:30:46',
#      'status_id': '6',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '7',
#      'runs_open': '-',
#      'runs_total': '38',
#      'km_open': '-',
#      'km_total': '22,58',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '8',
#      'blue_runs_open': '-',
#      'blue_runs_total': '12',
#      'red_runs_open': '-',
#      'red_runs_total': '15',
#      'black_runs_open': '-',
#      'black_runs_total': '3',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Viernes 20 de Enero de 2023.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Itinerarios de Skimo',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 67},
#         {'element_name': 'Esquí de fondo',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 29}]}]}]},
#   {'id': 955,
#    'name': 'Valle Laciana - Leitariegos',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '23/01/2023',
#    'opening_confirmed': 1,
#    'closing_date': '29/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:53:53',
#      'status_id': '2',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '8',
#      'runs_open': '-',
#      'runs_total': '14',
#      'km_open': '-',
#      'km_total': '8,4',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '4',
#      'blue_runs_open': '-',
#      'blue_runs_total': '4',
#      'red_runs_open': '-',
#      'red_runs_total': '6',
#      'black_runs_open': '-',
#      'black_runs_total': '-',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30}]}]},
#     {'date': '2023-01-20',
#      'updated': '2023-01-20 08:51:46',
#      'status_id': '2',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '8',
#      'runs_open': '-',
#      'runs_total': '14',
#      'km_open': '-',
#      'km_total': '8,4',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '4',
#      'blue_runs_open': '-',
#      'blue_runs_total': '4',
#      'red_runs_open': '-',
#      'red_runs_total': '6',
#      'black_runs_open': '-',
#      'black_runs_total': '-',
#      'special_runs': 0,
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30}]}]}]},
#   {'id': 4685,
#    'name': 'Javalambre',
#    'downhill_skiing': 1,
#    'nordic_skiing': 0,
#    'opening_date': '21/01/2023',
#    'opening_confirmed': 1,
#    'closing_date': '19/03/2023',
#    'snowreports': [{'date': '2023-01-19',
#      'updated': '2023-01-19 08:53:53',
#      'status_id': '6',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '9',
#      'runs_open': '-',
#      'runs_total': '18',
#      'km_open': '-',
#      'km_total': '15',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '5',
#      'blue_runs_open': '-',
#      'blue_runs_total': '9',
#      'red_runs_open': '-',
#      'red_runs_total': '1',
#      'black_runs_open': '-',
#      'black_runs_total': '-',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '3',
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Sábado 21 de Enero de 2023.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Trineos',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 32}]}]},
#     {'date': '2023-01-20',
#      'updated': '2023-01-20 08:51:46',
#      'status_id': '6',
#      'status_open': '0',
#      'status_text': 'Cerrada',
#      'lifts_open': '-',
#      'lifts_total': '9',
#      'runs_open': '-',
#      'runs_total': '18',
#      'km_open': '-',
#      'km_total': '15',
#      'snowdepth_min': '-',
#      'snowdepth_max': '-',
#      'snow_quality': '-',
#      'green_runs_open': '-',
#      'green_runs_total': '5',
#      'blue_runs_open': '-',
#      'blue_runs_total': '9',
#      'red_runs_open': '-',
#      'red_runs_total': '1',
#      'black_runs_open': '-',
#      'black_runs_total': '-',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '3',
#      'avalanche_risk': '-1',
#      'avalanche_risk_text': 'sin información',
#      'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Sábado 21 de Enero de 2023.',
#      'extended_elements': [{'group_name': 'Actividades',
#        'group_items': [{'element_name': 'Snowpark',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 30},
#         {'element_name': 'Trineos',
#          'element_status_id': '0',
#          'element_status_text': 'Cerrado',
#          'element_icon': 32}]}]},
#     {'date': '2023-01-21',
#      'updated': '2023-01-21 08:46:18',
#      'status_id': '1',
#      'status_open': '1',
#      'status_text': 'Abierta',
#      'lifts_open': '4',
#      'lifts_total': '9',
#      'runs_open': '6',
#      'runs_total': '18',
#      'km_open': '5',
#      'km_total': '15',
#      'snowdepth_min': '20',
#      'snowdepth_max': '50',
#      'snow_quality': 'Polvo/Dura',
#      'green_runs_open': '4',
#      'green_runs_total': '5',
#      'blue_runs_open': '2',
#      'blue_runs_total': '9',
#      'red_runs_open': '-',
#      'red_runs_total': '1',
#      'black_runs_open': '-',
#      'black_runs_total': '-',
#      'special_runs': 1,
#      'special_runs_text': 'Itinerarios',
#      'special_runs_open': '-',
#      'special_runs_total': '3',
#      'avalanche_risk': '1',
#      'avalanche_risk_text': 'Débil',
#      'extended_elements': [{'group_name': 'Actividades',
# ...
#    {'status_id': '4', 'status_open': '0', 'status_text': 'Cerrada Meteo'},
#    {'status_id': '2', 'status_open': '0', 'status_text': 'Cerrada'},
#    {'status_id': '3', 'status_open': '0', 'status_text': 'Uso turístico'},
#    {'status_id': '6', 'status_open': '0', 'status_text': 'Cerrada'}],
#   'avalanche_risk': [{'avalanche_level': '-1',
#     'avalanche_text': 'sin información'},
#    {'avalanche_level': '0', 'avalanche_text': 'Sin Riesgo'},
#    {'avalanche_level': '1', 'avalanche_text': 'Débil'},
#    {'avalanche_level': '2', 'avalanche_text': 'Limitado'},
#    {'avalanche_level': '3', 'avalanche_text': 'Notable'},
#    {'avalanche_level': '4', 'avalanche_text': 'Fuerte'},
#    {'avalanche_level': '5', 'avalanche_text': 'Extremo'}],
#   'elements_status': [{'element_status_id': '1',
#     'element_status_open': '1',
#     'element_status_text': 'Abierto'},
#    {'element_status_id': '0',
#     'element_status_open': '0',
#     'element_status_text': 'Cerrado'},
#    {'element_status_id': '4',
#     'element_status_open': '1',
#     'element_status_text': 'Apertura parcial'},
#    {'element_status_id': '2',
#     'element_status_open': '1',
#     'element_status_text': 'Previsión apertura'},
#    {'element_status_id': '5',
#     'element_status_open': '0',
#     'element_status_text': 'Uso Turístico'},
#    {'element_status_id': '3',
#     'element_status_open': '0',
#     'element_status_text': 'Acceso libre'},
#    {'element_status_id': '-1',
#     'element_status_open': '0',
#     'element_status_text': 'Sin información'}],
#   'elements_icons': [{'element_icon_id': '1',
#     'element_icon_text': 'Remonte: Teleférico',
#     'element_icon_file': 'icon_tf.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tf.svg'},
#    {'element_icon_id': '2',
#     'element_icon_text': 'Remonte: Telecabina',
#     'element_icon_file': 'icon_tc.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tc.svg'},
#    {'element_icon_id': '3',
#     'element_icon_text': 'Remonte: Telesilla desembragable',
#     'element_icon_file': 'icon_tsd.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tsd.svg'},
#    {'element_icon_id': '4',
#     'element_icon_text': 'Remonte: Telesilla fija',
#     'element_icon_file': 'icon_tsf.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tsf.svg'},
#    {'element_icon_id': '5',
#     'element_icon_text': 'Remonte: Telesquí',
#     'element_icon_file': 'icon_tk.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tk.svg'},
#    {'element_icon_id': '6',
#     'element_icon_text': 'Remonte: Alfombra',
#     'element_icon_file': 'icon_alfombra.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alfombra.svg'},
#    {'element_icon_id': '7',
#     'element_icon_text': 'Remonte: Telecuerda',
#     'element_icon_file': 'icon_cuerda.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_cuerda.svg'},
#    {'element_icon_id': '8',
#     'element_icon_text': 'Color verde',
#     'element_icon_file': 'icon_color_verde.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_verde.svg'},
#    {'element_icon_id': '9',
#     'element_icon_text': 'Color azul',
#     'element_icon_file': 'icon_color_azul.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_azul.svg'},
#    {'element_icon_id': '10',
#     'element_icon_text': 'Color rojo',
#     'element_icon_file': 'icon_color_rojo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_rojo.svg'},
#    {'element_icon_id': '11',
#     'element_icon_text': 'Color negro',
#     'element_icon_file': 'icon_color_negro.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_negro.svg'},
#    {'element_icon_id': '12',
#     'element_icon_text': 'Color amarillo',
#     'element_icon_file': 'icon_color_amarillo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_amarillo.svg'},
#    {'element_icon_id': '13',
#     'element_icon_text': 'Esquí verde',
#     'element_icon_file': 'icon_esqui_verde.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_verde.svg'},
#    {'element_icon_id': '14',
#     'element_icon_text': 'Esquí azul',
#     'element_icon_file': 'icon_esqui_azul.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_azul.svg'},
#    {'element_icon_id': '15',
#     'element_icon_text': 'Esquí rojo',
#     'element_icon_file': 'icon_esqui_rojo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_rojo.svg'},
#    {'element_icon_id': '16',
#     'element_icon_text': 'Esquí negro',
#     'element_icon_file': 'icon_esqui_negro.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_negro.svg'},
#    {'element_icon_id': '17',
#     'element_icon_text': 'Esquí amarillo',
#     'element_icon_file': 'icon_esqui_amarillo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_amarillo.svg'},
#    {'element_icon_id': '18',
#     'element_icon_text': 'Pista verde',
#     'element_icon_file': 'icon_pista_verde.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_verde.svg'},
#    {'element_icon_id': '19',
#     'element_icon_text': 'Pista azul',
#     'element_icon_file': 'icon_pista_azul.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_azul.svg'},
#    {'element_icon_id': '20',
#     'element_icon_text': 'Pista roja',
#     'element_icon_file': 'icon_pista_roja.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_roja.svg'},
#    {'element_icon_id': '21',
#     'element_icon_text': 'Pista negra',
#     'element_icon_file': 'icon_pista_negra.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_negra.svg'},
#    {'element_icon_id': '22',
#     'element_icon_text': 'Itinerario',
#     'element_icon_file': 'icon_pista_itinerario.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_itinerario.svg'},
#    {'element_icon_id': '23',
#     'element_icon_text': 'Fondo verde',
#     'element_icon_file': 'icon_fondo_verde.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_verde.svg'},
#    {'element_icon_id': '24',
#     'element_icon_text': 'Fondo azul',
#     'element_icon_file': 'icon_fondo_azul.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_azul.svg'},
#    {'element_icon_id': '25',
#     'element_icon_text': 'Fondo roja',
#     'element_icon_file': 'icon_fondo_rojo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_rojo.svg'},
#    {'element_icon_id': '26',
#     'element_icon_text': 'Fondo negra',
#     'element_icon_file': 'icon_fondo_negra.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_negra.svg'},
#    {'element_icon_id': '27',
#     'element_icon_text': 'Fondo amarilla',
#     'element_icon_file': 'icon_fondo_amarilla.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_amarilla.svg'},
#    {'element_icon_id': '43',
#     'element_icon_text': 'Snow verde',
#     'element_icon_file': 'icon_snow_verde.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_verde.svg'},
#    {'element_icon_id': '44',
#     'element_icon_text': 'Snow azul',
#     'element_icon_file': 'icon_snow_azul.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_azul.svg'},
#    {'element_icon_id': '45',
#     'element_icon_text': 'Snow rojo',
#     'element_icon_file': 'icon_snow_rojo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_rojo.svg'},
#    {'element_icon_id': '46',
#     'element_icon_text': 'Snow negro',
#     'element_icon_file': 'icon_snow_negro.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_negro.svg'},
#    {'element_icon_id': '47',
#     'element_icon_text': 'Snow amarillo',
#     'element_icon_file': 'icon_snow_amarillo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_amarillo.svg'},
#    {'element_icon_id': '62',
#     'element_icon_text': 'Skimo verde',
#     'element_icon_file': 'icon_skimo_verde.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_verde.svg'},
#    {'element_icon_id': '63',
#     'element_icon_text': 'Skimo azul',
#     'element_icon_file': 'icon_skimo_azul.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_azul.svg'},
#    {'element_icon_id': '64',
#     'element_icon_text': 'Skimo rojo',
#     'element_icon_file': 'icon_skimo_rojo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_rojo.svg'},
#    {'element_icon_id': '65',
#     'element_icon_text': 'Skimo negro',
#     'element_icon_file': 'icon_skimo_negro.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_negro.svg'},
#    {'element_icon_id': '66',
#     'element_icon_text': 'Skimo amarillo',
#     'element_icon_file': 'icon_skimo_amarillo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_amarillo.svg'},
#    {'element_icon_id': '28',
#     'element_icon_text': 'Esquí alpino',
#     'element_icon_file': 'icon_esqui.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui.svg'},
#    {'element_icon_id': '29',
#     'element_icon_text': 'Esquí nórdico',
#     'element_icon_file': 'icon_fondo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo.svg'},
#    {'element_icon_id': '67',
#     'element_icon_text': 'Esquí de Montaña',
#     'element_icon_file': 'icon_skimo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo.svg'},
#    {'element_icon_id': '30',
#     'element_icon_text': 'Snowpark',
#     'element_icon_file': 'icon_snowpark.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snowpark.svg'},
#    {'element_icon_id': '48',
#     'element_icon_text': 'Estadio competición',
#     'element_icon_file': 'icon_estadio.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_estadio.svg'},
#    {'element_icon_id': '56',
#     'element_icon_text': 'Montaña',
#     'element_icon_file': 'icon_mountain.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_mountain.svg'},
#    {'element_icon_id': '31',
#     'element_icon_text': 'Enlace',
#     'element_icon_file': 'icon_enlace.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_enlace.svg'},
#    {'element_icon_id': '57',
#     'element_icon_text': 'Ruta',
#     'element_icon_file': 'icon_ruta.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_ruta.svg'},
#    {'element_icon_id': '58',
#     'element_icon_text': 'Bosque',
#     'element_icon_file': 'icon_bosque.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bosque.svg'},
#    {'element_icon_id': '68',
#     'element_icon_text': 'Copo de Nieve',
#     'element_icon_file': 'icon_copo.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_copo.svg'},
#    {'element_icon_id': '32',
#     'element_icon_text': 'Trineos',
#     'element_icon_file': 'icon_trineos.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_trineos.svg'},
#    {'element_icon_id': '33',
#     'element_icon_text': 'Raquetas',
#     'element_icon_file': 'icon_raquetas.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_raquetas.svg'},
#    {'element_icon_id': '34',
#     'element_icon_text': 'Excursión',
#     'element_icon_file': 'icon_excursion.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_excursion.svg'},
#    {'element_icon_id': '42',
#     'element_icon_text': 'Tubby',
#     'element_icon_file': 'icon_tubby.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tubby.svg'},
#    {'element_icon_id': '49',
#     'element_icon_text': 'Zona de juegos',
#     'element_icon_file': 'icon_juegos.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_juegos.svg'},
#    {'element_icon_id': '69',
#     'element_icon_text': 'Mushing',
#     'element_icon_file': 'icon_mushing.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_mushing.svg'},
#    {'element_icon_id': '71',
#     'element_icon_text': 'Skijöring',
#     'element_icon_file': 'icon_skijoring.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skijoring.svg'},
#    {'element_icon_id': '70',
#     'element_icon_text': 'Motonieve',
#     'element_icon_file': 'icon_motonieve.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_motonieve.svg'},
#    {'element_icon_id': '72',
#     'element_icon_text': 'Pisapistas',
#     'element_icon_file': 'icon_pisapistas.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pisapistas.svg'},
#    {'element_icon_id': '35',
#     'element_icon_text': 'Restaurante',
#     'element_icon_file': 'icon_restaurante.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_restaurante.svg'},
#    {'element_icon_id': '36',
#     'element_icon_text': 'Cafetería',
#     'element_icon_file': 'icon_cafeteria.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_cafeteria.svg'},
#    {'element_icon_id': '37',
#     'element_icon_text': 'Bar',
#     'element_icon_file': 'icon_bar.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bar.svg'},
#    {'element_icon_id': '38',
#     'element_icon_text': 'Forfaits',
#     'element_icon_file': 'icon_forfait.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_forfait.svg'},
#    {'element_icon_id': '39',
#     'element_icon_text': 'Alquiler',
#     'element_icon_file': 'icon_alquiler.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alquiler.svg'},
#    {'element_icon_id': '40',
#     'element_icon_text': 'Escuela',
#     'element_icon_file': 'icon_escuela.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_escuela.svg'},
#    {'element_icon_id': '50',
#     'element_icon_text': 'Guardería',
#     'element_icon_file': 'icon_guarderia.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_guarderia.svg'},
#    {'element_icon_id': '41',
#     'element_icon_text': 'Tienda',
#     'element_icon_file': 'icon_tienda.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tienda.svg'},
#    {'element_icon_id': '51',
#     'element_icon_text': 'Servicios',
#     'element_icon_file': 'icon_servicios.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_servicios.svg'},
#    {'element_icon_id': '59',
#     'element_icon_text': 'Alojamiento',
#     'element_icon_file': 'icon_alojamiento.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alojamiento.svg'},
#    {'element_icon_id': '61',
#     'element_icon_text': 'Refugio',
#     'element_icon_file': 'icon_refugio.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_refugio.svg'},
#    {'element_icon_id': '60',
#     'element_icon_text': 'Parking',
#     'element_icon_file': 'icon_parking.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_parking.svg'},
#    {'element_icon_id': '52',
#     'element_icon_text': 'Entretenimiento',
#     'element_icon_file': 'icon_juguete.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_juguete.svg'},
#    {'element_icon_id': '53',
#     'element_icon_text': 'Familia',
#     'element_icon_file': 'icon_familia.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_familia.svg'},
#    {'element_icon_id': '54',
#     'element_icon_text': 'Niños',
#     'element_icon_file': 'icon_kids.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_kids.svg'},
#    {'element_icon_id': '55',
#     'element_icon_text': 'Bebé',
#     'element_icon_file': 'icon_bebe.svg',
#     'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bebe.svg'}]}}

# %%
from tqdm.notebook import tqdm

# %%
data = []


for i in res.json():
    
    data.append(requests.get(url).json())

# %%
data
# Out:
# [{'resorts': [{'id': 22001,
#     'name': 'Alp 2500',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '02/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '10/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '19',
#       'lifts_total': '33',
#       'runs_open': '59',
#       'runs_total': '138',
#       'km_open': '71',
#       'km_total': '145',
#       'snowdepth_min': '40',
#       'snowdepth_max': '75',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '18',
#       'green_runs_total': '29',
#       'blue_runs_open': '24',
#       'blue_runs_total': '49',
#       'red_runs_open': '15',
#       'red_runs_total': '44',
#       'black_runs_open': '2',
#       'black_runs_total': '16',
#       'special_runs': 0,
#       'avalanche_risk': '0',
#       'avalanche_risk_text': 'Sin Riesgo',
#       'extended_elements': [{'group_name': 'Dominio',
#         'group_items': [{'element_name': 'Conexión Alp2500',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '31'}]}]},
#      {'date': '2023-01-20',
#       'updated': '2023-01-20 11:24:09',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '12',
#       'lifts_total': '33',
#       'runs_open': '41',
#       'runs_total': '138',
#       'km_open': '40',
#       'km_total': '145',
#       'snowdepth_min': '40',
#       'snowdepth_max': '75',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '19',
#       'green_runs_total': '29',
#       'blue_runs_open': '17',
#       'blue_runs_total': '49',
#       'red_runs_open': '5',
#       'red_runs_total': '44',
#       'black_runs_open': '-',
#       'black_runs_total': '16',
#       'special_runs': 0,
#       'avalanche_risk': '0',
#       'avalanche_risk_text': 'Sin Riesgo',
#       'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#       'extended_elements': [{'group_name': 'Dominio',
#         'group_items': [{'element_name': 'Conexión Alp2500',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': '31'}]}]},
#      {'date': '2023-01-22',
#       'updated': '2023-01-22 10:26:03',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '16',
#       'lifts_total': '33',
#       'runs_open': '44',
#       'runs_total': '138',
#       'km_open': '42',
#       'km_total': '145',
#       'snowdepth_min': '40',
#       'snowdepth_max': '75',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '20',
#       'green_runs_total': '29',
#       'blue_runs_open': '19',
#       'blue_runs_total': '49',
#       'red_runs_open': '5',
#       'red_runs_total': '44',
#       'black_runs_open': '-',
#       'black_runs_total': '16',
#       'special_runs': 0,
#       'avalanche_risk': '0',
#       'avalanche_risk_text': 'Sin Riesgo',
#       'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#       'extended_elements': [{'group_name': 'Dominio',
#         'group_items': [{'element_name': 'Conexión Alp2500',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': '31'}]}]}]},
#    {'id': 20,
#     'name': 'La Molina',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '03/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '10/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 09:17:53',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '8',
#       'lifts_total': '16',
#       'runs_open': '25',
#       'runs_total': '66',
#       'km_open': '22',
#       'km_total': '71',
#       'snowdepth_min': '40',
#       'snowdepth_max': '65',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '11',
#       'green_runs_total': '20',
#       'blue_runs_open': '7',
#       'blue_runs_total': '18',
#       'red_runs_open': '6',
#       'red_runs_total': '22',
#       'black_runs_open': '1',
#       'black_runs_total': '6',
#       'special_runs': 0,
#       'avalanche_risk': '0',
#       'avalanche_risk_text': 'Sin Riesgo',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 30},
#          {'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 67},
#          {'element_name': 'Raquetas',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 33},
#          {'element_name': 'Trineos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 32}]},
#        {'group_name': 'Dominio',
#         'group_items': [{'element_name': 'Conexión Alp2500',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '31'}]}]}]},
#    {'id': 19,
#     'name': 'Masella',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '02/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '10/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '11',
#       'lifts_total': '17',
#       'runs_open': '34',
#       'runs_total': '72',
#       'km_open': '49',
#       'km_total': '74',
#       'snowdepth_min': '40',
#       'snowdepth_max': '75',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '7',
#       'green_runs_total': '9',
#       'blue_runs_open': '17',
#       'blue_runs_total': '31',
#       'red_runs_open': '9',
#       'red_runs_total': '22',
#       'black_runs_open': '1',
#       'black_runs_total': '10',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'extended_elements': [{'group_name': 'Dominio',
#         'group_items': [{'element_name': 'Conexión Alp2500',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '31'}]}]}]},
#    {'id': 16,
#     'name': 'Baqueira Beret',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '26/11/2022',
#     'opening_confirmed': 1,
#     'closing_date': '10/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '30',
#       'lifts_total': '36',
#       'runs_open': '69',
#       'runs_total': '116',
#       'km_open': '110',
#       'km_total': '170',
#       'snowdepth_min': '60',
#       'snowdepth_max': '90',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '5',
#       'green_runs_total': '5',
#       'blue_runs_open': '35',
#       'blue_runs_total': '43',
#       'red_runs_open': '26',
#       'red_runs_total': '48',
#       'black_runs_open': '3',
#       'black_runs_total': '17',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '3',
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Esquí de fondo',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 29}]},
#        {'group_name': 'Sectores',
#         'group_items': [{'element_name': 'Baqueira',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Beret',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Bonaigua',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Baciver',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': '56'}]}]},
#      {'date': '2023-01-20',
#       'updated': '2023-01-20 11:24:09',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '27',
#       'lifts_total': '36',
#       'runs_open': '56',
#       'runs_total': '116',
#       'km_open': '100',
#       'km_total': '170',
#       'snowdepth_min': '90',
#       'snowdepth_max': '130',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '5',
#       'green_runs_total': '5',
#       'blue_runs_open': '28',
#       'blue_runs_total': '43',
#       'red_runs_open': '20',
#       'red_runs_total': '48',
#       'black_runs_open': '3',
#       'black_runs_total': '17',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '3',
#       'avalanche_risk': '4',
#       'avalanche_risk_text': 'Fuerte',
#       'comment': 'Previsión de condiciones meteorológicas adversas. Los datos de apertura podrían verse condicionados en función de la evolución de las condiciones meteorológicas.',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Esquí de fondo',
#           'element_status_id': '2',
#           'element_status_text': 'Previsión apertura',
#           'element_icon': 29}]},
#        {'group_name': 'Sectores',
#         'group_items': [{'element_name': 'Baqueira',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Beret',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Bonaigua',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Baciver',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': '56'}]}]}]},
#    {'id': 17,
#     'name': 'Boí Taüll',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '02/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '10/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '6',
#       'lifts_total': '10',
#       'runs_open': '24',
#       'runs_total': '43',
#       'km_open': '26',
#       'km_total': '46',
#       'snowdepth_min': '65',
#       'snowdepth_max': '130',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '6',
#       'green_runs_total': '6',
#       'blue_runs_open': '5',
#       'blue_runs_total': '6',
#       'red_runs_open': '7',
#       'red_runs_total': '15',
#       'black_runs_open': '6',
#       'black_runs_total': '16',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 67,
#           'element_num_open': '2',
#           'element_num_total': '4',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '5.54',
#           'element_km_total': '11.76'},
#          {'element_name': 'Trineos',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 32}]}]}]},
#    {'id': 18,
#     'name': 'Espot',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '02/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '31/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 09:17:53',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '5',
#       'lifts_total': '5',
#       'runs_open': '10',
#       'runs_total': '22',
#       'km_open': '11',
#       'km_total': '25',
#       'snowdepth_min': '50',
#       'snowdepth_max': '80',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '2',
#       'green_runs_total': '2',
#       'blue_runs_open': '4',
#       'blue_runs_total': '10',
#       'red_runs_open': '3',
#       'red_runs_total': '6',
#       'black_runs_open': '1',
#       'black_runs_total': '4',
#       'special_runs': 0,
#       'avalanche_risk': '5',
#       'avalanche_risk_text': 'Extremo',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 67},
#          {'element_name': 'Raquetas',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 33,
#           'element_num_open': '1',
#           'element_num_total': '3',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '0.8',
#           'element_km_total': '5.2'},
#          {'element_name': 'Trineos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 32}]}]}]},
#    {'id': 21,
#     'name': 'Port Ainé',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '02/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '10/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '7',
#       'lifts_total': '7',
#       'runs_open': '21',
#       'runs_total': '25',
#       'km_open': '24',
#       'km_total': '27',
#       'snowdepth_min': '45',
#       'snowdepth_max': '75',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '6',
#       'green_runs_total': '6',
#       'blue_runs_open': '4',
#       'blue_runs_total': '4',
#       'red_runs_open': '8',
#       'red_runs_total': '11',
#       'black_runs_open': '3',
#       'black_runs_total': '4',
#       'special_runs': 0,
#       'avalanche_risk': '2',
#       'avalanche_risk_text': 'Limitado',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 67,
#           'element_num_open': '4',
#           'element_num_total': '4',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '9.66',
#           'element_km_total': '9.66'},
#          {'element_name': 'Raquetas',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 33,
#           'element_num_open': '2',
#           'element_num_total': '3',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '8.64',
#           'element_km_total': '18.01'},
#          {'element_name': 'Trineos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 32}]}]},
#      {'date': '2023-01-20',
#       'updated': '2023-01-20 11:24:09',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '5',
#       'lifts_total': '7',
#       'runs_open': '6',
#       'runs_total': '25',
#       'km_open': '7',
#       'km_total': '27',
#       'snowdepth_min': '45',
#       'snowdepth_max': '75',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '4',
#       'green_runs_total': '6',
#       'blue_runs_open': '-',
#       'blue_runs_total': '4',
#       'red_runs_open': '1',
#       'red_runs_total': '11',
#       'black_runs_open': '1',
#       'black_runs_total': '4',
#       'special_runs': 0,
#       'avalanche_risk': '2',
#       'avalanche_risk_text': 'Limitado',
#       'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 67,
#           'element_num_open': '4',
#           'element_num_total': '4',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '9.66',
#           'element_km_total': '9.66'},
#          {'element_name': 'Raquetas',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 33,
#           'element_num_open': '2',
#           'element_num_total': '3',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '8.64',
#           'element_km_total': '18.01'},
#          {'element_name': 'Trineos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 32}]}]}]},
#    {'id': 22,
#     'name': 'Port del Comte',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '03/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '10/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '5',
#       'lifts_total': '17',
#       'runs_open': '6',
#       'runs_total': '39',
#       'km_open': '6',
#       'km_total': '50',
#       'snowdepth_min': '20',
#       'snowdepth_max': '35',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '5',
#       'green_runs_total': '8',
#       'blue_runs_open': '1',
#       'blue_runs_total': '13',
#       'red_runs_open': '-',
#       'red_runs_total': '12',
#       'black_runs_open': '-',
#       'black_runs_total': '6',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'extended_elements': [{'group_name': 'Sectores',
#         'group_items': [{'element_name': 'Donadó',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Sucre',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': '56'},
#          {'element_name': 'Estivella',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': '56'}]}]}]},
#    {'id': 2412,
#     'name': 'Tavascán',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '07/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '6',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '3',
#       'runs_open': '-',
#       'runs_total': '7',
#       'km_open': '-',
#       'km_total': '7',
#       'snowdepth_min': '60',
#       'snowdepth_max': '90',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '-',
#       'green_runs_total': '2',
#       'blue_runs_open': '-',
#       'blue_runs_total': '1',
#       'red_runs_open': '-',
#       'red_runs_total': '2',
#       'black_runs_open': '-',
#       'black_runs_total': '2',
#       'special_runs': 0,
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'comment': 'Pistas de esquí cerradas. Previsión de reapertura: viernes 20 de enero de 2023.'}]},
#    {'id': 23,
#     'name': 'Vall de Nuria',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '03/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 09:17:53',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '3',
#       'lifts_total': '7',
#       'runs_open': '3',
#       'runs_total': '11',
#       'km_open': '1',
#       'km_total': '8',
#       'snowdepth_min': '30',
#       'snowdepth_max': '50',
#       'snow_quality': 'Polvo/Dura',
#       'green_runs_open': '3',
#       'green_runs_total': '3',
#       'blue_runs_open': '-',
#       'blue_runs_total': '3',
#       'red_runs_open': '-',
#       'red_runs_total': '3',
#       'black_runs_open': '-',
#       'black_runs_total': '2',
#       'special_runs': 0,
#       'avalanche_risk': '0',
#       'avalanche_risk_text': 'Sin Riesgo',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 67,
#           'element_num_open': '1',
#           'element_num_total': '2',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '1.85',
#           'element_km_total': '2.98'},
#          {'element_name': 'Raquetas',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 33,
#           'element_num_open': '1',
#           'element_num_total': '7',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '1.85',
#           'element_km_total': '11.84'},
#          {'element_name': 'Trineos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 32}]}]},
#      {'date': '2023-01-20',
#       'updated': '2023-01-20 08:49:02',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '3',
#       'lifts_total': '7',
#       'runs_open': '3',
#       'runs_total': '11',
#       'km_open': '1',
#       'km_total': '8',
#       'snowdepth_min': '30',
#       'snowdepth_max': '50',
#       'snow_quality': 'Polvo/Dura',
#       'green_runs_open': '3',
#       'green_runs_total': '3',
#       'blue_runs_open': '-',
#       'blue_runs_total': '3',
#       'red_runs_open': '-',
#       'red_runs_total': '3',
#       'black_runs_open': '-',
#       'black_runs_total': '2',
#       'special_runs': 0,
#       'avalanche_risk': '0',
#       'avalanche_risk_text': 'Sin Riesgo',
#       'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 67,
#           'element_num_open': '1',
#           'element_num_total': '2',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '1.85',
#           'element_km_total': '2.98'},
#          {'element_name': 'Raquetas',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 33,
#           'element_num_open': '3',
#           'element_num_total': '7',
#           'element_num_text': 'itinerarios',
#           'element_km_open': '7.65',
#           'element_km_total': '11.84'},
#          {'element_name': 'Trineos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 32}]}]}]},
#    {'id': 24,
#     'name': 'Vallter',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '04/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '22/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 09:17:53',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '3',
#       'lifts_total': '10',
#       'runs_open': '2',
#       'runs_total': '13',
#       'km_open': '1',
#       'km_total': '13',
#       'snowdepth_min': '15',
#       'snowdepth_max': '40',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '2',
#       'green_runs_total': '3',
#       'blue_runs_open': '-',
#       'blue_runs_total': '4',
#       'red_runs_open': '-',
#       'red_runs_total': '6',
#       'black_runs_open': '-',
#       'black_runs_total': '-',
#       'special_runs': 0,
#       'avalanche_risk': '0',
#       'avalanche_risk_text': 'Sin Riesgo',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 67},
#          {'element_name': 'Trineos',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 32}]}]}]},
#    {'id': 22003,
#     'name': '100K Astún - Candanchú',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '03/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '20',
#       'lifts_total': '37',
#       'runs_open': '43',
#       'runs_total': '118',
#       'km_open': '39,5',
#       'km_total': '100,5',
#       'snowdepth_min': '100',
#       'snowdepth_max': '160',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '16',
#       'green_runs_total': '17',
#       'blue_runs_open': '16',
#       'blue_runs_total': '32',
#       'red_runs_open': '10',
#       'red_runs_total': '40',
#       'black_runs_open': '1',
#       'black_runs_total': '19',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '10',
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable'}]},
#    {'id': 7,
#     'name': 'Astún',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '03/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '11',
#       'lifts_total': '15',
#       'runs_open': '24',
#       'runs_total': '61',
#       'km_open': '24',
#       'km_total': '50',
#       'snowdepth_min': '125',
#       'snowdepth_max': '155',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '5',
#       'green_runs_total': '5',
#       'blue_runs_open': '12',
#       'blue_runs_total': '18',
#       'red_runs_open': '7',
#       'red_runs_total': '22',
#       'black_runs_open': '-',
#       'black_runs_total': '6',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '10',
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Trineos',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 32}]}]}]},
#    {'id': 8,
#     'name': 'Candanchú',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '03/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '9',
#       'lifts_total': '22',
#       'runs_open': '19',
#       'runs_total': '57',
#       'km_open': '15,5',
#       'km_total': '50,5',
#       'snowdepth_min': '100',
#       'snowdepth_max': '160',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '11',
#       'green_runs_total': '12',
#       'blue_runs_open': '4',
#       'blue_runs_total': '14',
#       'red_runs_open': '3',
#       'red_runs_total': '18',
#       'black_runs_open': '1',
#       'black_runs_total': '13',
#       'special_runs': 0,
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Trineos',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 32}]}]}]},
#    {'id': 9,
#     'name': 'Cerler',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '06/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '9',
#       'lifts_total': '20',
#       'runs_open': '14',
#       'runs_total': '72',
#       'km_open': '39',
#       'km_total': '80',
#       'snowdepth_min': '35',
#       'snowdepth_max': '75',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '6',
#       'green_runs_total': '10',
#       'blue_runs_open': '8',
#       'blue_runs_total': '19',
#       'red_runs_open': '-',
#       'red_runs_total': '27',
#       'black_runs_open': '-',
#       'black_runs_total': '16',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '1',
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones.',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 67},
#          {'element_name': 'Raquetas',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 33}]}]}]},
#    {'id': 22002,
#     'name': 'Formigal - Panticosa',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '03/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '27',
#       'lifts_total': '37',
#       'runs_open': '77',
#       'runs_total': '147',
#       'km_open': '90',
#       'km_total': '182',
#       'snowdepth_min': '30',
#       'snowdepth_max': '170',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '11',
#       'green_runs_total': '12',
#       'blue_runs_open': '25',
#       'blue_runs_total': '36',
#       'red_runs_open': '31',
#       'red_runs_total': '52',
#       'black_runs_open': '10',
#       'black_runs_total': '42',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '5',
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'comment': 'Previsión de condiciones meteorológicas adversas. Los datos de apertura podrían verse condicionados en función de la evolución de las condiciones meteorológicas.'}]},
#    {'id': 10,
#     'name': 'Formigal',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '03/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '19',
#       'lifts_total': '22',
#       'runs_open': '59',
#       'runs_total': '102',
#       'km_open': '73',
#       'km_total': '143',
#       'snowdepth_min': '45',
#       'snowdepth_max': '170',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '5',
#       'green_runs_total': '6',
#       'blue_runs_open': '20',
#       'blue_runs_total': '20',
#       'red_runs_open': '24',
#       'red_runs_total': '35',
#       'black_runs_open': '10',
#       'black_runs_total': '37',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '4',
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'comment': 'Previsión de condiciones meteorológicas adversas. Los datos de apertura podrían verse condicionados en función de la evolución de las condiciones meteorológicas.',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': 30}]},
#        {'group_name': 'Valles',
#         'group_items': [{'element_name': 'Sextas - Tres Hombres',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Izas - Sarrios',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Anayet',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Portalet',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'}]}]}]},
#    {'id': 11,
#     'name': 'Panticosa',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '26/12/2022',
#     'opening_confirmed': 1,
#     'closing_date': '09/04/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:52:22',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '8',
#       'lifts_total': '15',
#       'runs_open': '18',
#       'runs_total': '45',
#       'km_open': '17',
#       'km_total': '39',
#       'snowdepth_min': '30',
#       'snowdepth_max': '110',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '6',
#       'green_runs_total': '6',
#       'blue_runs_open': '5',
#       'blue_runs_total': '16',
#       'red_runs_open': '7',
#       'red_runs_total': '17',
#       'black_runs_open': '-',
#       'black_runs_total': '5',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '1',
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'comment': 'Apertura parcial debida a condiciones meteorológicas adversas. Los datos de apertura podrían variar a lo largo del día en función de la evolución de las condiciones meteorológicas y los trabajos de acondicionamiento de pistas y remontes.',
#       'extended_elements': [{'group_name': 'Valles',
#         'group_items': [{'element_name': 'Petrosos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Sabocos',
#           'element_status_id': '2',
#           'element_status_text': 'Previsión apertura',
#           'element_icon': '56'}]}]},
#      {'date': '2023-01-20',
#       'updated': '2023-01-20 11:24:09',
#       'status_id': '1',
#       'status_open': '1',
#       'status_text': 'Abierta',
#       'lifts_open': '10',
#       'lifts_total': '15',
#       'runs_open': '23',
#       'runs_total': '45',
#       'km_open': '18',
#       'km_total': '39',
#       'snowdepth_min': '50',
#       'snowdepth_max': '150',
#       'snow_quality': 'Polvo',
#       'green_runs_open': '6',
#       'green_runs_total': '6',
#       'blue_runs_open': '9',
#       'blue_runs_total': '16',
#       'red_runs_open': '8',
#       'red_runs_total': '17',
#       'black_runs_open': '-',
#       'black_runs_total': '5',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '1',
#       'avalanche_risk': '3',
#       'avalanche_risk_text': 'Notable',
#       'comment': 'Previsión de condiciones meteorológicas adversas. Los datos de apertura podrían verse condicionados en función de la evolución de las condiciones meteorológicas.',
#       'extended_elements': [{'group_name': 'Valles',
#         'group_items': [{'element_name': 'Petrosos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'},
#          {'element_name': 'Sabocos',
#           'element_status_id': '1',
#           'element_status_text': 'Abierto',
#           'element_icon': '56'}]}]}]},
#    {'id': 15,
#     'name': 'Alto Campoo',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '20/01/2023',
#     'opening_confirmed': 1,
#     'closing_date': '28/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 12:03:15',
#       'status_id': '6',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '12',
#       'runs_open': '-',
#       'runs_total': '23',
#       'km_open': '-',
#       'km_total': '30,38',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '4',
#       'blue_runs_open': '-',
#       'blue_runs_total': '10',
#       'red_runs_open': '-',
#       'red_runs_total': '9',
#       'black_runs_open': '-',
#       'black_runs_total': '-',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Viernes 20 de Enero de 2023.',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Esquí de fondo',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 29}]}]}]},
#    {'id': 5448,
#     'name': 'Fuentes de Invierno',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '22/01/2023',
#     'opening_confirmed': 1,
#     'closing_date': '23/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:53:53',
#       'status_id': '2',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '5',
#       'runs_open': '-',
#       'runs_total': '15',
#       'km_open': '-',
#       'km_total': '8,76',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '3',
#       'blue_runs_open': '-',
#       'blue_runs_total': '3',
#       'red_runs_open': '-',
#       'red_runs_total': '6',
#       'black_runs_open': '-',
#       'black_runs_total': '3',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información'}]},
#    {'id': 25,
#     'name': 'Manzaneda',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '27/01/2023',
#     'opening_confirmed': 1,
#     'closing_date': '07/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:53:53',
#       'status_id': '6',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '6',
#       'runs_open': '-',
#       'runs_total': '23',
#       'km_open': '-',
#       'km_total': '16,75',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '1',
#       'blue_runs_open': '-',
#       'blue_runs_total': '13',
#       'red_runs_open': '-',
#       'red_runs_total': '8',
#       'black_runs_open': '-',
#       'black_runs_total': '1',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Viernes 20 de Enero de 2023.'}]},
#    {'id': 14,
#     'name': 'San Isidro',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '21/01/2023',
#     'opening_confirmed': 1,
#     'closing_date': '26/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:53:53',
#       'status_id': '2',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '15',
#       'runs_open': '-',
#       'runs_total': '32',
#       'km_open': '-',
#       'km_total': '31,1',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '6',
#       'blue_runs_open': '-',
#       'blue_runs_total': '8',
#       'red_runs_open': '-',
#       'red_runs_total': '13',
#       'black_runs_open': '-',
#       'black_runs_total': '4',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '1',
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Esquí de fondo',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 29}]}]}]},
#    {'id': 13,
#     'name': 'Valgrande-Pajares',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '22/01/2023',
#     'opening_confirmed': 1,
#     'closing_date': '15/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 19:30:46',
#       'status_id': '6',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '7',
#       'runs_open': '-',
#       'runs_total': '38',
#       'km_open': '-',
#       'km_total': '22,58',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '8',
#       'blue_runs_open': '-',
#       'blue_runs_total': '12',
#       'red_runs_open': '-',
#       'red_runs_total': '15',
#       'black_runs_open': '-',
#       'black_runs_total': '3',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Viernes 20 de Enero de 2023.',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Itinerarios de Skimo',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 67},
#          {'element_name': 'Esquí de fondo',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 29}]}]}]},
#    {'id': 955,
#     'name': 'Valle Laciana - Leitariegos',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '23/01/2023',
#     'opening_confirmed': 1,
#     'closing_date': '29/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:53:53',
#       'status_id': '2',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '8',
#       'runs_open': '-',
#       'runs_total': '14',
#       'km_open': '-',
#       'km_total': '8,4',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '4',
#       'blue_runs_open': '-',
#       'blue_runs_total': '4',
#       'red_runs_open': '-',
#       'red_runs_total': '6',
#       'black_runs_open': '-',
#       'black_runs_total': '-',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30}]}]},
#      {'date': '2023-01-20',
#       'updated': '2023-01-20 08:51:46',
#       'status_id': '2',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '8',
#       'runs_open': '-',
#       'runs_total': '14',
#       'km_open': '-',
#       'km_total': '8,4',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '4',
#       'blue_runs_open': '-',
#       'blue_runs_total': '4',
#       'red_runs_open': '-',
#       'red_runs_total': '6',
#       'black_runs_open': '-',
#       'black_runs_total': '-',
#       'special_runs': 0,
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30}]}]}]},
#    {'id': 4685,
#     'name': 'Javalambre',
#     'downhill_skiing': 1,
#     'nordic_skiing': 0,
#     'opening_date': '21/01/2023',
#     'opening_confirmed': 1,
#     'closing_date': '19/03/2023',
#     'snowreports': [{'date': '2023-01-19',
#       'updated': '2023-01-19 08:53:53',
#       'status_id': '6',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '9',
#       'runs_open': '-',
#       'runs_total': '18',
#       'km_open': '-',
#       'km_total': '15',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '5',
#       'blue_runs_open': '-',
#       'blue_runs_total': '9',
#       'red_runs_open': '-',
#       'red_runs_total': '1',
#       'black_runs_open': '-',
#       'black_runs_total': '-',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '3',
#       'avalanche_risk': '-1',
#       'avalanche_risk_text': 'sin información',
#       'comment': 'Pistas de esquí cerradas. Fecha prevista de inicio de la temporada: Sábado 21 de Enero de 2023.',
#       'extended_elements': [{'group_name': 'Actividades',
#         'group_items': [{'element_name': 'Snowpark',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 30},
#          {'element_name': 'Trineos',
#           'element_status_id': '0',
#           'element_status_text': 'Cerrado',
#           'element_icon': 32}]}]},
#      {'date': '2023-01-20',
#       'updated': '2023-01-20 08:51:46',
#       'status_id': '6',
#       'status_open': '0',
#       'status_text': 'Cerrada',
#       'lifts_open': '-',
#       'lifts_total': '9',
#       'runs_open': '-',
#       'runs_total': '18',
#       'km_open': '-',
#       'km_total': '15',
#       'snowdepth_min': '-',
#       'snowdepth_max': '-',
#       'snow_quality': '-',
#       'green_runs_open': '-',
#       'green_runs_total': '5',
#       'blue_runs_open': '-',
#       'blue_runs_total': '9',
#       'red_runs_open': '-',
#       'red_runs_total': '1',
#       'black_runs_open': '-',
#       'black_runs_total': '-',
#       'special_runs': 1,
#       'special_runs_text': 'Itinerarios',
#       'special_runs_open': '-',
#       'special_runs_total': '3',
#       'avalanche_risk': '-1',
# ...
#    'avalanche_risk': [{'avalanche_level': '-1',
#      'avalanche_text': 'sin información'},
#     {'avalanche_level': '0', 'avalanche_text': 'Sin Riesgo'},
#     {'avalanche_level': '1', 'avalanche_text': 'Débil'},
#     {'avalanche_level': '2', 'avalanche_text': 'Limitado'},
#     {'avalanche_level': '3', 'avalanche_text': 'Notable'},
#     {'avalanche_level': '4', 'avalanche_text': 'Fuerte'},
#     {'avalanche_level': '5', 'avalanche_text': 'Extremo'}],
#    'elements_status': [{'element_status_id': '1',
#      'element_status_open': '1',
#      'element_status_text': 'Abierto'},
#     {'element_status_id': '0',
#      'element_status_open': '0',
#      'element_status_text': 'Cerrado'},
#     {'element_status_id': '4',
#      'element_status_open': '1',
#      'element_status_text': 'Apertura parcial'},
#     {'element_status_id': '2',
#      'element_status_open': '1',
#      'element_status_text': 'Previsión apertura'},
#     {'element_status_id': '5',
#      'element_status_open': '0',
#      'element_status_text': 'Uso Turístico'},
#     {'element_status_id': '3',
#      'element_status_open': '0',
#      'element_status_text': 'Acceso libre'},
#     {'element_status_id': '-1',
#      'element_status_open': '0',
#      'element_status_text': 'Sin información'}],
#    'elements_icons': [{'element_icon_id': '1',
#      'element_icon_text': 'Remonte: Teleférico',
#      'element_icon_file': 'icon_tf.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tf.svg'},
#     {'element_icon_id': '2',
#      'element_icon_text': 'Remonte: Telecabina',
#      'element_icon_file': 'icon_tc.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tc.svg'},
#     {'element_icon_id': '3',
#      'element_icon_text': 'Remonte: Telesilla desembragable',
#      'element_icon_file': 'icon_tsd.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tsd.svg'},
#     {'element_icon_id': '4',
#      'element_icon_text': 'Remonte: Telesilla fija',
#      'element_icon_file': 'icon_tsf.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tsf.svg'},
#     {'element_icon_id': '5',
#      'element_icon_text': 'Remonte: Telesquí',
#      'element_icon_file': 'icon_tk.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tk.svg'},
#     {'element_icon_id': '6',
#      'element_icon_text': 'Remonte: Alfombra',
#      'element_icon_file': 'icon_alfombra.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alfombra.svg'},
#     {'element_icon_id': '7',
#      'element_icon_text': 'Remonte: Telecuerda',
#      'element_icon_file': 'icon_cuerda.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_cuerda.svg'},
#     {'element_icon_id': '8',
#      'element_icon_text': 'Color verde',
#      'element_icon_file': 'icon_color_verde.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_verde.svg'},
#     {'element_icon_id': '9',
#      'element_icon_text': 'Color azul',
#      'element_icon_file': 'icon_color_azul.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_azul.svg'},
#     {'element_icon_id': '10',
#      'element_icon_text': 'Color rojo',
#      'element_icon_file': 'icon_color_rojo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_rojo.svg'},
#     {'element_icon_id': '11',
#      'element_icon_text': 'Color negro',
#      'element_icon_file': 'icon_color_negro.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_negro.svg'},
#     {'element_icon_id': '12',
#      'element_icon_text': 'Color amarillo',
#      'element_icon_file': 'icon_color_amarillo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_amarillo.svg'},
#     {'element_icon_id': '13',
#      'element_icon_text': 'Esquí verde',
#      'element_icon_file': 'icon_esqui_verde.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_verde.svg'},
#     {'element_icon_id': '14',
#      'element_icon_text': 'Esquí azul',
#      'element_icon_file': 'icon_esqui_azul.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_azul.svg'},
#     {'element_icon_id': '15',
#      'element_icon_text': 'Esquí rojo',
#      'element_icon_file': 'icon_esqui_rojo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_rojo.svg'},
#     {'element_icon_id': '16',
#      'element_icon_text': 'Esquí negro',
#      'element_icon_file': 'icon_esqui_negro.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_negro.svg'},
#     {'element_icon_id': '17',
#      'element_icon_text': 'Esquí amarillo',
#      'element_icon_file': 'icon_esqui_amarillo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_amarillo.svg'},
#     {'element_icon_id': '18',
#      'element_icon_text': 'Pista verde',
#      'element_icon_file': 'icon_pista_verde.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_verde.svg'},
#     {'element_icon_id': '19',
#      'element_icon_text': 'Pista azul',
#      'element_icon_file': 'icon_pista_azul.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_azul.svg'},
#     {'element_icon_id': '20',
#      'element_icon_text': 'Pista roja',
#      'element_icon_file': 'icon_pista_roja.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_roja.svg'},
#     {'element_icon_id': '21',
#      'element_icon_text': 'Pista negra',
#      'element_icon_file': 'icon_pista_negra.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_negra.svg'},
#     {'element_icon_id': '22',
#      'element_icon_text': 'Itinerario',
#      'element_icon_file': 'icon_pista_itinerario.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_itinerario.svg'},
#     {'element_icon_id': '23',
#      'element_icon_text': 'Fondo verde',
#      'element_icon_file': 'icon_fondo_verde.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_verde.svg'},
#     {'element_icon_id': '24',
#      'element_icon_text': 'Fondo azul',
#      'element_icon_file': 'icon_fondo_azul.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_azul.svg'},
#     {'element_icon_id': '25',
#      'element_icon_text': 'Fondo roja',
#      'element_icon_file': 'icon_fondo_rojo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_rojo.svg'},
#     {'element_icon_id': '26',
#      'element_icon_text': 'Fondo negra',
#      'element_icon_file': 'icon_fondo_negra.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_negra.svg'},
#     {'element_icon_id': '27',
#      'element_icon_text': 'Fondo amarilla',
#      'element_icon_file': 'icon_fondo_amarilla.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_amarilla.svg'},
#     {'element_icon_id': '43',
#      'element_icon_text': 'Snow verde',
#      'element_icon_file': 'icon_snow_verde.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_verde.svg'},
#     {'element_icon_id': '44',
#      'element_icon_text': 'Snow azul',
#      'element_icon_file': 'icon_snow_azul.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_azul.svg'},
#     {'element_icon_id': '45',
#      'element_icon_text': 'Snow rojo',
#      'element_icon_file': 'icon_snow_rojo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_rojo.svg'},
#     {'element_icon_id': '46',
#      'element_icon_text': 'Snow negro',
#      'element_icon_file': 'icon_snow_negro.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_negro.svg'},
#     {'element_icon_id': '47',
#      'element_icon_text': 'Snow amarillo',
#      'element_icon_file': 'icon_snow_amarillo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_amarillo.svg'},
#     {'element_icon_id': '62',
#      'element_icon_text': 'Skimo verde',
#      'element_icon_file': 'icon_skimo_verde.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_verde.svg'},
#     {'element_icon_id': '63',
#      'element_icon_text': 'Skimo azul',
#      'element_icon_file': 'icon_skimo_azul.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_azul.svg'},
#     {'element_icon_id': '64',
#      'element_icon_text': 'Skimo rojo',
#      'element_icon_file': 'icon_skimo_rojo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_rojo.svg'},
#     {'element_icon_id': '65',
#      'element_icon_text': 'Skimo negro',
#      'element_icon_file': 'icon_skimo_negro.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_negro.svg'},
#     {'element_icon_id': '66',
#      'element_icon_text': 'Skimo amarillo',
#      'element_icon_file': 'icon_skimo_amarillo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_amarillo.svg'},
#     {'element_icon_id': '28',
#      'element_icon_text': 'Esquí alpino',
#      'element_icon_file': 'icon_esqui.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui.svg'},
#     {'element_icon_id': '29',
#      'element_icon_text': 'Esquí nórdico',
#      'element_icon_file': 'icon_fondo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo.svg'},
#     {'element_icon_id': '67',
#      'element_icon_text': 'Esquí de Montaña',
#      'element_icon_file': 'icon_skimo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo.svg'},
#     {'element_icon_id': '30',
#      'element_icon_text': 'Snowpark',
#      'element_icon_file': 'icon_snowpark.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snowpark.svg'},
#     {'element_icon_id': '48',
#      'element_icon_text': 'Estadio competición',
#      'element_icon_file': 'icon_estadio.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_estadio.svg'},
#     {'element_icon_id': '56',
#      'element_icon_text': 'Montaña',
#      'element_icon_file': 'icon_mountain.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_mountain.svg'},
#     {'element_icon_id': '31',
#      'element_icon_text': 'Enlace',
#      'element_icon_file': 'icon_enlace.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_enlace.svg'},
#     {'element_icon_id': '57',
#      'element_icon_text': 'Ruta',
#      'element_icon_file': 'icon_ruta.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_ruta.svg'},
#     {'element_icon_id': '58',
#      'element_icon_text': 'Bosque',
#      'element_icon_file': 'icon_bosque.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bosque.svg'},
#     {'element_icon_id': '68',
#      'element_icon_text': 'Copo de Nieve',
#      'element_icon_file': 'icon_copo.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_copo.svg'},
#     {'element_icon_id': '32',
#      'element_icon_text': 'Trineos',
#      'element_icon_file': 'icon_trineos.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_trineos.svg'},
#     {'element_icon_id': '33',
#      'element_icon_text': 'Raquetas',
#      'element_icon_file': 'icon_raquetas.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_raquetas.svg'},
#     {'element_icon_id': '34',
#      'element_icon_text': 'Excursión',
#      'element_icon_file': 'icon_excursion.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_excursion.svg'},
#     {'element_icon_id': '42',
#      'element_icon_text': 'Tubby',
#      'element_icon_file': 'icon_tubby.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tubby.svg'},
#     {'element_icon_id': '49',
#      'element_icon_text': 'Zona de juegos',
#      'element_icon_file': 'icon_juegos.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_juegos.svg'},
#     {'element_icon_id': '69',
#      'element_icon_text': 'Mushing',
#      'element_icon_file': 'icon_mushing.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_mushing.svg'},
#     {'element_icon_id': '71',
#      'element_icon_text': 'Skijöring',
#      'element_icon_file': 'icon_skijoring.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skijoring.svg'},
#     {'element_icon_id': '70',
#      'element_icon_text': 'Motonieve',
#      'element_icon_file': 'icon_motonieve.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_motonieve.svg'},
#     {'element_icon_id': '72',
#      'element_icon_text': 'Pisapistas',
#      'element_icon_file': 'icon_pisapistas.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pisapistas.svg'},
#     {'element_icon_id': '35',
#      'element_icon_text': 'Restaurante',
#      'element_icon_file': 'icon_restaurante.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_restaurante.svg'},
#     {'element_icon_id': '36',
#      'element_icon_text': 'Cafetería',
#      'element_icon_file': 'icon_cafeteria.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_cafeteria.svg'},
#     {'element_icon_id': '37',
#      'element_icon_text': 'Bar',
#      'element_icon_file': 'icon_bar.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bar.svg'},
#     {'element_icon_id': '38',
#      'element_icon_text': 'Forfaits',
#      'element_icon_file': 'icon_forfait.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_forfait.svg'},
#     {'element_icon_id': '39',
#      'element_icon_text': 'Alquiler',
#      'element_icon_file': 'icon_alquiler.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alquiler.svg'},
#     {'element_icon_id': '40',
#      'element_icon_text': 'Escuela',
#      'element_icon_file': 'icon_escuela.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_escuela.svg'},
#     {'element_icon_id': '50',
#      'element_icon_text': 'Guardería',
#      'element_icon_file': 'icon_guarderia.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_guarderia.svg'},
#     {'element_icon_id': '41',
#      'element_icon_text': 'Tienda',
#      'element_icon_file': 'icon_tienda.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tienda.svg'},
#     {'element_icon_id': '51',
#      'element_icon_text': 'Servicios',
#      'element_icon_file': 'icon_servicios.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_servicios.svg'},
#     {'element_icon_id': '59',
#      'element_icon_text': 'Alojamiento',
#      'element_icon_file': 'icon_alojamiento.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alojamiento.svg'},
#     {'element_icon_id': '61',
#      'element_icon_text': 'Refugio',
#      'element_icon_file': 'icon_refugio.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_refugio.svg'},
#     {'element_icon_id': '60',
#      'element_icon_text': 'Parking',
#      'element_icon_file': 'icon_parking.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_parking.svg'},
#     {'element_icon_id': '52',
#      'element_icon_text': 'Entretenimiento',
#      'element_icon_file': 'icon_juguete.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_juguete.svg'},
#     {'element_icon_id': '53',
#      'element_icon_text': 'Familia',
#      'element_icon_file': 'icon_familia.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_familia.svg'},
#     {'element_icon_id': '54',
#      'element_icon_text': 'Niños',
#      'element_icon_file': 'icon_kids.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_kids.svg'},
#     {'element_icon_id': '55',
#      'element_icon_text': 'Bebé',
#      'element_icon_file': 'icon_bebe.svg',
#      'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bebe.svg'}]}}]

# %%
resorts = res.json()['resorts']

# %%
alp_2500 = resorts[0]
la_molina = resorts[1]
masella = resorts[2]
baqueira_beret = resorts[3]
boi_taull = resorts[4]
espot = resorts[5]
port_aine = resorts[6]
port_del_comte = resorts[7]
tavascan = resorts[8]
vall_de_nuria = resorts[9]
vallter = resorts[10]
astun_candanchu = resorts[11]
astun = resorts[12]
candanchu = resorts[13]
cerler = resorts[14]
formigal_panticosa = resorts[15]
formigal = resorts[16]
panticosa = resorts[17]
alto_campoo = resorts[18]
fuentes_de_invierno = resorts[19]
manzaneda = resorts[20]
san_isidro = resorts[21]
valgrande_pajares = resorts[22]
valle_laciana_leitariegos = resorts[23]
javalambre = resorts[24]
punto_de_nieve_santa_ines = resorts[25]
valdelinares = resorts[26]
valdezcaray = resorts[27]
la_pinilla = resorts[28]
navacerrada = resorts[29]
la_covatilla = resorts[30]
valdesqui = resorts[31]
sierranevada = resorts[32]
grandvalira = resorts[33]
ordino_arcalis = resorts[34]
pal_arinsal = resorts[35]
ski_canaro = resorts[36]
artouste = resorts[37]
gourette = resorts[38]
la_pierre_saint_martin = resorts[39]
cauterets = resorts[40]
cauterets_cirque_du_lys = resorts[41]
cauterets_pont_despagne = resorts[42]
gavarnie_gedre = resorts[43]
grand_tourmalet = resorts[44]
hautacam = resorts[45]
luz_ardiden = resorts[46]
peyragudes = resorts[47]
piau_engaly = resorts[48]
saint_lary = resorts[49]
val_louron = resorts[50]
bourg_doueil = resorts[51]
le_mourtis = resorts[52]
luchon_superbagneres = resorts[53]
ascou_pailheres = resorts[54]
ax_3_domaines = resorts[55]
goulier_neige = resorts[56]
guzet = resorts[57]
les_monts_dolmes = resorts[58]
mijanes_donezan = resorts[59]
camurac = resorts[60]
cambre_daze = resorts[61]
font_romeu_pyrenees_2000 = resorts[62]
formigueres = resorts[63]
la_quillane = resorts[64]
les_angles = resorts[65]
porte_puymorens = resorts[66]
serra_da_estrela = resorts[67]

# %%
espot.keys()
# Out:
# dict_keys(['id', 'name', 'downhill_skiing', 'nordic_skiing', 'opening_date', 'opening_confirmed', 'closing_date', 'snowreports'])

# %%
espot['snowreports'][0]['extended_elements'][0]
# Out:
# {'group_name': 'Actividades',
#  'group_items': [{'element_name': 'Itinerarios de Skimo',
#    'element_status_id': '0',
#    'element_status_text': 'Cerrado',
#    'element_icon': 67},
#   {'element_name': 'Raquetas',
#    'element_status_id': '1',
#    'element_status_text': 'Abierto',
#    'element_icon': 33,
#    'element_num_open': '1',
#    'element_num_total': '3',
#    'element_num_text': 'itinerarios',
#    'element_km_open': '0.8',
#    'element_km_total': '5.2'},
#   {'element_name': 'Trineos',
#    'element_status_id': '1',
#    'element_status_text': 'Abierto',
#    'element_icon': 32}]}

# %%
df_baqueira = pd.DataFrame(baqueira_beret['snowreports'])

# %%
pd.DataFrame(grandvalira['snowreports']).T
# Out:
#                                                                      0
# date                                                        2023-01-19
# updated                                            2023-01-19 08:57:46
# status_id                                                            1
# status_open                                                          1
# status_text                                                    Abierta
# lifts_open                                                          58
# lifts_total                                                         74
# runs_open                                                           90
# runs_total                                                         138
# km_open                                                            132
# km_total                                                           210
# snowdepth_min                                                       25
# snowdepth_max                                                       60
# snow_quality                                                     Polvo
# green_runs_open                                                     21
# green_runs_total                                                    24
# blue_runs_open                                                      41
# blue_runs_total                                                     54
# red_runs_open                                                       22
# red_runs_total                                                      42
# black_runs_open                                                      6
# black_runs_total                                                    18
# special_runs                                                         0
# avalanche_risk                                                       3
# avalanche_risk_text                                            Notable
# extended_elements    [{'group_name': 'Actividades', 'group_items': ...

# %%
database = res.json()['database']

# %%
database
# Out:
# {'snowreports_status': [{'status_id': '1',
#    'status_open': '1',
#    'status_text': 'Abierta'},
#   {'status_id': '5', 'status_open': '1', 'status_text': 'Previsión Apertura'},
#   {'status_id': '4', 'status_open': '0', 'status_text': 'Cerrada Meteo'},
#   {'status_id': '2', 'status_open': '0', 'status_text': 'Cerrada'},
#   {'status_id': '3', 'status_open': '0', 'status_text': 'Uso turístico'},
#   {'status_id': '6', 'status_open': '0', 'status_text': 'Cerrada'}],
#  'avalanche_risk': [{'avalanche_level': '-1',
#    'avalanche_text': 'sin información'},
#   {'avalanche_level': '0', 'avalanche_text': 'Sin Riesgo'},
#   {'avalanche_level': '1', 'avalanche_text': 'Débil'},
#   {'avalanche_level': '2', 'avalanche_text': 'Limitado'},
#   {'avalanche_level': '3', 'avalanche_text': 'Notable'},
#   {'avalanche_level': '4', 'avalanche_text': 'Fuerte'},
#   {'avalanche_level': '5', 'avalanche_text': 'Extremo'}],
#  'elements_status': [{'element_status_id': '1',
#    'element_status_open': '1',
#    'element_status_text': 'Abierto'},
#   {'element_status_id': '0',
#    'element_status_open': '0',
#    'element_status_text': 'Cerrado'},
#   {'element_status_id': '4',
#    'element_status_open': '1',
#    'element_status_text': 'Apertura parcial'},
#   {'element_status_id': '2',
#    'element_status_open': '1',
#    'element_status_text': 'Previsión apertura'},
#   {'element_status_id': '5',
#    'element_status_open': '0',
#    'element_status_text': 'Uso Turístico'},
#   {'element_status_id': '3',
#    'element_status_open': '0',
#    'element_status_text': 'Acceso libre'},
#   {'element_status_id': '-1',
#    'element_status_open': '0',
#    'element_status_text': 'Sin información'}],
#  'elements_icons': [{'element_icon_id': '1',
#    'element_icon_text': 'Remonte: Teleférico',
#    'element_icon_file': 'icon_tf.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tf.svg'},
#   {'element_icon_id': '2',
#    'element_icon_text': 'Remonte: Telecabina',
#    'element_icon_file': 'icon_tc.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tc.svg'},
#   {'element_icon_id': '3',
#    'element_icon_text': 'Remonte: Telesilla desembragable',
#    'element_icon_file': 'icon_tsd.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tsd.svg'},
#   {'element_icon_id': '4',
#    'element_icon_text': 'Remonte: Telesilla fija',
#    'element_icon_file': 'icon_tsf.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tsf.svg'},
#   {'element_icon_id': '5',
#    'element_icon_text': 'Remonte: Telesquí',
#    'element_icon_file': 'icon_tk.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tk.svg'},
#   {'element_icon_id': '6',
#    'element_icon_text': 'Remonte: Alfombra',
#    'element_icon_file': 'icon_alfombra.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alfombra.svg'},
#   {'element_icon_id': '7',
#    'element_icon_text': 'Remonte: Telecuerda',
#    'element_icon_file': 'icon_cuerda.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_cuerda.svg'},
#   {'element_icon_id': '8',
#    'element_icon_text': 'Color verde',
#    'element_icon_file': 'icon_color_verde.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_verde.svg'},
#   {'element_icon_id': '9',
#    'element_icon_text': 'Color azul',
#    'element_icon_file': 'icon_color_azul.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_azul.svg'},
#   {'element_icon_id': '10',
#    'element_icon_text': 'Color rojo',
#    'element_icon_file': 'icon_color_rojo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_rojo.svg'},
#   {'element_icon_id': '11',
#    'element_icon_text': 'Color negro',
#    'element_icon_file': 'icon_color_negro.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_negro.svg'},
#   {'element_icon_id': '12',
#    'element_icon_text': 'Color amarillo',
#    'element_icon_file': 'icon_color_amarillo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_color_amarillo.svg'},
#   {'element_icon_id': '13',
#    'element_icon_text': 'Esquí verde',
#    'element_icon_file': 'icon_esqui_verde.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_verde.svg'},
#   {'element_icon_id': '14',
#    'element_icon_text': 'Esquí azul',
#    'element_icon_file': 'icon_esqui_azul.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_azul.svg'},
#   {'element_icon_id': '15',
#    'element_icon_text': 'Esquí rojo',
#    'element_icon_file': 'icon_esqui_rojo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_rojo.svg'},
#   {'element_icon_id': '16',
#    'element_icon_text': 'Esquí negro',
#    'element_icon_file': 'icon_esqui_negro.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_negro.svg'},
#   {'element_icon_id': '17',
#    'element_icon_text': 'Esquí amarillo',
#    'element_icon_file': 'icon_esqui_amarillo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui_amarillo.svg'},
#   {'element_icon_id': '18',
#    'element_icon_text': 'Pista verde',
#    'element_icon_file': 'icon_pista_verde.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_verde.svg'},
#   {'element_icon_id': '19',
#    'element_icon_text': 'Pista azul',
#    'element_icon_file': 'icon_pista_azul.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_azul.svg'},
#   {'element_icon_id': '20',
#    'element_icon_text': 'Pista roja',
#    'element_icon_file': 'icon_pista_roja.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_roja.svg'},
#   {'element_icon_id': '21',
#    'element_icon_text': 'Pista negra',
#    'element_icon_file': 'icon_pista_negra.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_negra.svg'},
#   {'element_icon_id': '22',
#    'element_icon_text': 'Itinerario',
#    'element_icon_file': 'icon_pista_itinerario.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pista_itinerario.svg'},
#   {'element_icon_id': '23',
#    'element_icon_text': 'Fondo verde',
#    'element_icon_file': 'icon_fondo_verde.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_verde.svg'},
#   {'element_icon_id': '24',
#    'element_icon_text': 'Fondo azul',
#    'element_icon_file': 'icon_fondo_azul.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_azul.svg'},
#   {'element_icon_id': '25',
#    'element_icon_text': 'Fondo roja',
#    'element_icon_file': 'icon_fondo_rojo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_rojo.svg'},
#   {'element_icon_id': '26',
#    'element_icon_text': 'Fondo negra',
#    'element_icon_file': 'icon_fondo_negra.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_negra.svg'},
#   {'element_icon_id': '27',
#    'element_icon_text': 'Fondo amarilla',
#    'element_icon_file': 'icon_fondo_amarilla.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo_amarilla.svg'},
#   {'element_icon_id': '43',
#    'element_icon_text': 'Snow verde',
#    'element_icon_file': 'icon_snow_verde.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_verde.svg'},
#   {'element_icon_id': '44',
#    'element_icon_text': 'Snow azul',
#    'element_icon_file': 'icon_snow_azul.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_azul.svg'},
#   {'element_icon_id': '45',
#    'element_icon_text': 'Snow rojo',
#    'element_icon_file': 'icon_snow_rojo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_rojo.svg'},
#   {'element_icon_id': '46',
#    'element_icon_text': 'Snow negro',
#    'element_icon_file': 'icon_snow_negro.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_negro.svg'},
#   {'element_icon_id': '47',
#    'element_icon_text': 'Snow amarillo',
#    'element_icon_file': 'icon_snow_amarillo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snow_amarillo.svg'},
#   {'element_icon_id': '62',
#    'element_icon_text': 'Skimo verde',
#    'element_icon_file': 'icon_skimo_verde.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_verde.svg'},
#   {'element_icon_id': '63',
#    'element_icon_text': 'Skimo azul',
#    'element_icon_file': 'icon_skimo_azul.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_azul.svg'},
#   {'element_icon_id': '64',
#    'element_icon_text': 'Skimo rojo',
#    'element_icon_file': 'icon_skimo_rojo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_rojo.svg'},
#   {'element_icon_id': '65',
#    'element_icon_text': 'Skimo negro',
#    'element_icon_file': 'icon_skimo_negro.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_negro.svg'},
#   {'element_icon_id': '66',
#    'element_icon_text': 'Skimo amarillo',
#    'element_icon_file': 'icon_skimo_amarillo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo_amarillo.svg'},
#   {'element_icon_id': '28',
#    'element_icon_text': 'Esquí alpino',
#    'element_icon_file': 'icon_esqui.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_esqui.svg'},
#   {'element_icon_id': '29',
#    'element_icon_text': 'Esquí nórdico',
#    'element_icon_file': 'icon_fondo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_fondo.svg'},
#   {'element_icon_id': '67',
#    'element_icon_text': 'Esquí de Montaña',
#    'element_icon_file': 'icon_skimo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skimo.svg'},
#   {'element_icon_id': '30',
#    'element_icon_text': 'Snowpark',
#    'element_icon_file': 'icon_snowpark.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_snowpark.svg'},
#   {'element_icon_id': '48',
#    'element_icon_text': 'Estadio competición',
#    'element_icon_file': 'icon_estadio.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_estadio.svg'},
#   {'element_icon_id': '56',
#    'element_icon_text': 'Montaña',
#    'element_icon_file': 'icon_mountain.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_mountain.svg'},
#   {'element_icon_id': '31',
#    'element_icon_text': 'Enlace',
#    'element_icon_file': 'icon_enlace.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_enlace.svg'},
#   {'element_icon_id': '57',
#    'element_icon_text': 'Ruta',
#    'element_icon_file': 'icon_ruta.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_ruta.svg'},
#   {'element_icon_id': '58',
#    'element_icon_text': 'Bosque',
#    'element_icon_file': 'icon_bosque.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bosque.svg'},
#   {'element_icon_id': '68',
#    'element_icon_text': 'Copo de Nieve',
#    'element_icon_file': 'icon_copo.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_copo.svg'},
#   {'element_icon_id': '32',
#    'element_icon_text': 'Trineos',
#    'element_icon_file': 'icon_trineos.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_trineos.svg'},
#   {'element_icon_id': '33',
#    'element_icon_text': 'Raquetas',
#    'element_icon_file': 'icon_raquetas.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_raquetas.svg'},
#   {'element_icon_id': '34',
#    'element_icon_text': 'Excursión',
#    'element_icon_file': 'icon_excursion.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_excursion.svg'},
#   {'element_icon_id': '42',
#    'element_icon_text': 'Tubby',
#    'element_icon_file': 'icon_tubby.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tubby.svg'},
#   {'element_icon_id': '49',
#    'element_icon_text': 'Zona de juegos',
#    'element_icon_file': 'icon_juegos.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_juegos.svg'},
#   {'element_icon_id': '69',
#    'element_icon_text': 'Mushing',
#    'element_icon_file': 'icon_mushing.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_mushing.svg'},
#   {'element_icon_id': '71',
#    'element_icon_text': 'Skijöring',
#    'element_icon_file': 'icon_skijoring.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_skijoring.svg'},
#   {'element_icon_id': '70',
#    'element_icon_text': 'Motonieve',
#    'element_icon_file': 'icon_motonieve.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_motonieve.svg'},
#   {'element_icon_id': '72',
#    'element_icon_text': 'Pisapistas',
#    'element_icon_file': 'icon_pisapistas.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_pisapistas.svg'},
#   {'element_icon_id': '35',
#    'element_icon_text': 'Restaurante',
#    'element_icon_file': 'icon_restaurante.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_restaurante.svg'},
#   {'element_icon_id': '36',
#    'element_icon_text': 'Cafetería',
#    'element_icon_file': 'icon_cafeteria.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_cafeteria.svg'},
#   {'element_icon_id': '37',
#    'element_icon_text': 'Bar',
#    'element_icon_file': 'icon_bar.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bar.svg'},
#   {'element_icon_id': '38',
#    'element_icon_text': 'Forfaits',
#    'element_icon_file': 'icon_forfait.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_forfait.svg'},
#   {'element_icon_id': '39',
#    'element_icon_text': 'Alquiler',
#    'element_icon_file': 'icon_alquiler.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alquiler.svg'},
#   {'element_icon_id': '40',
#    'element_icon_text': 'Escuela',
#    'element_icon_file': 'icon_escuela.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_escuela.svg'},
#   {'element_icon_id': '50',
#    'element_icon_text': 'Guardería',
#    'element_icon_file': 'icon_guarderia.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_guarderia.svg'},
#   {'element_icon_id': '41',
#    'element_icon_text': 'Tienda',
#    'element_icon_file': 'icon_tienda.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_tienda.svg'},
#   {'element_icon_id': '51',
#    'element_icon_text': 'Servicios',
#    'element_icon_file': 'icon_servicios.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_servicios.svg'},
#   {'element_icon_id': '59',
#    'element_icon_text': 'Alojamiento',
#    'element_icon_file': 'icon_alojamiento.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_alojamiento.svg'},
#   {'element_icon_id': '61',
#    'element_icon_text': 'Refugio',
#    'element_icon_file': 'icon_refugio.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_refugio.svg'},
#   {'element_icon_id': '60',
#    'element_icon_text': 'Parking',
#    'element_icon_file': 'icon_parking.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_parking.svg'},
#   {'element_icon_id': '52',
#    'element_icon_text': 'Entretenimiento',
#    'element_icon_file': 'icon_juguete.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_juguete.svg'},
#   {'element_icon_id': '53',
#    'element_icon_text': 'Familia',
#    'element_icon_file': 'icon_familia.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_familia.svg'},
#   {'element_icon_id': '54',
#    'element_icon_text': 'Niños',
#    'element_icon_file': 'icon_kids.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_kids.svg'},
#   {'element_icon_id': '55',
#    'element_icon_text': 'Bebé',
#    'element_icon_file': 'icon_bebe.svg',
#    'element_icon_url': 'https://www.infonieve.es/images/partes/icon_bebe.svg'}]}

# %%
alp = pd.DataFrame(alp_2500)

# %%
alp1 = pd.DataFrame(alp_2500['snowreports'])

# %%
df_alp2500 = alp.join(alp1, how='left')

df_alp2500
# Out:
#       id      name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001  Alp 2500                1              0   02/12/2022
# 1  22001  Alp 2500                1              0   02/12/2022
# 2  22001  Alp 2500                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 1                  1   10/04/2023
# 2                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 1  {'date': '2023-01-20', 'updated': '2023-01-20 ...  2023-01-20
# 2  {'date': '2023-01-22', 'updated': '2023-01-22 ...  2023-01-22
#
#                updated  ... blue_runs_total red_runs_open red_runs_total  \
# 0  2023-01-19 08:52:22  ...              49            15             44
# 1  2023-01-20 11:24:09  ...              49             5             44
# 2  2023-01-22 10:26:03  ...              49             5             44
#
#   black_runs_open black_runs_total special_runs avalanche_risk  \
# 0               2               16            0              0
# 1               -               16            0              0
# 2               -               16            0              0
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 1          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 2          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
#
#                                              comment
# 0                                                NaN
# 1  Apertura parcial debida a condiciones meteorol...
# 2  Apertura parcial debida a condiciones meteorol...
#
# [3 rows x 35 columns]

# %%
df_alp2500.drop_duplicates(subset=['name'],inplace=True)

df_alp2500
# Out:
#       id      name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001  Alp 2500                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... blue_runs_total red_runs_open red_runs_total  \
# 0  2023-01-19 08:52:22  ...              49            15             44
#
#   black_runs_open black_runs_total special_runs avalanche_risk  \
# 0               2               16            0              0
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
#
#   comment
# 0     NaN
#
# [1 rows x 35 columns]

# %%
df_alp2500.insert(35, "snowpark", 0)

# %%
df_alp2500
# Out:
#       id      name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001  Alp 2500                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... red_runs_open red_runs_total black_runs_open  \
# 0  2023-01-19 08:52:22  ...            15             44               2
#
#   black_runs_total special_runs avalanche_risk avalanche_risk_text  \
# 0               16            0              0          Sin Riesgo
#
#                                    extended_elements comment snowpark
# 0  [{'group_name': 'Dominio', 'group_items': [{'e...     NaN        0
#
# [1 rows x 36 columns]

# %%
molina = pd.DataFrame(la_molina)
molina1 = pd.DataFrame(la_molina['snowreports'])

df_lamolina = molina.join(molina1, how='left')

df_lamolina
# Out:
#    id       name  downhill_skiing  nordic_skiing opening_date  \
# 0  20  La Molina                1              0   03/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... blue_runs_open blue_runs_total red_runs_open  \
# 0  2023-01-19 09:17:53  ...              7              18             6
#
#   red_runs_total black_runs_open black_runs_total special_runs avalanche_risk  \
# 0             22               1                6            0              0
#
#   avalanche_risk_text                                  extended_elements
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
#
# [1 rows x 34 columns]

# %%
df_lamolina.insert(34, "snowpark", 0)

# %%
df = pd.concat([df_alp2500,df_lamolina])

# %%
df.loc[df['snowpark']== 0 , 'snowpark'] = 1

# %%
df.iloc[0, 35] = 0

# %%
df.iloc[1].id
# Out:
# 20

# %%
mas = pd.DataFrame(masella)
mase = pd.DataFrame(masella['snowreports'])

df_masella = mas.join(mase, how='left')

df_masella
# Out:
#    id     name  downhill_skiing  nordic_skiing opening_date  \
# 0  19  Masella                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... blue_runs_open blue_runs_total red_runs_open  \
# 0  2023-01-19 08:52:22  ...             17              31             9
#
#   red_runs_total black_runs_open black_runs_total special_runs avalanche_risk  \
# 0             22               1               10            0             -1
#
#   avalanche_risk_text                                  extended_elements
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
#
# [1 rows x 34 columns]

# %%
df_masella.insert(34, "snowpark", 0)

# %%
df_masella
# Out:
#    id     name  downhill_skiing  nordic_skiing opening_date  \
# 0  19  Masella                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... blue_runs_total red_runs_open red_runs_total  \
# 0  2023-01-19 08:52:22  ...              31             9             22
#
#   black_runs_open black_runs_total special_runs avalanche_risk  \
# 0               1               10            0             -1
#
#   avalanche_risk_text                                  extended_elements  \
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
#
#   snowpark
# 0        0
#
# [1 rows x 35 columns]

# %%
df = pd.concat([df,df_masella])

df
# Out:
#       id       name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001   Alp 2500                1              0   02/12/2022
# 0     20  La Molina                1              0   03/12/2022
# 0     19    Masella                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... red_runs_open red_runs_total black_runs_open  \
# 0  2023-01-19 08:52:22  ...            15             44               2
# 0  2023-01-19 09:17:53  ...             6             22               1
# 0  2023-01-19 08:52:22  ...             9             22               1
#
#   black_runs_total special_runs avalanche_risk avalanche_risk_text  \
# 0               16            0              0          Sin Riesgo
# 0                6            0              0          Sin Riesgo
# 0               10            0             -1     sin información
#
#                                    extended_elements comment snowpark
# 0  [{'group_name': 'Dominio', 'group_items': [{'e...     NaN        0
# 0  [{'group_name': 'Actividades', 'group_items': ...     NaN        1
# 0  [{'group_name': 'Dominio', 'group_items': [{'e...     NaN        0
#
# [3 rows x 36 columns]

# %%
baq = pd.DataFrame(baqueira_beret)
baque = pd.DataFrame(baqueira_beret['snowreports'])

df_baqueira = baq.join(baque, how='left')

df_baqueira
# Out:
#    id            name  downhill_skiing  nordic_skiing opening_date  \
# 0  16  Baqueira Beret                1              0   26/11/2022
# 1  16  Baqueira Beret                1              0   26/11/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 1                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 1  {'date': '2023-01-20', 'updated': '2023-01-20 ...  2023-01-20
#
#                updated  ... black_runs_open black_runs_total special_runs  \
# 0  2023-01-19 08:52:22  ...               3               17            1
# 1  2023-01-20 11:24:09  ...               3               17            1
#
#   special_runs_text special_runs_open special_runs_total avalanche_risk  \
# 0       Itinerarios                 -                  3              3
# 1       Itinerarios                 -                  3              4
#
#   avalanche_risk_text                                  extended_elements  \
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 1              Fuerte  [{'group_name': 'Actividades', 'group_items': ...
#
#                                              comment
# 0                                                NaN
# 1  Previsión de condiciones meteorológicas advers...
#
# [2 rows x 38 columns]

# %%
df_baqueira.drop_duplicates(subset='name', inplace=True)

# %%
df_baqueira.insert(38, "snowpark", 1)

# %%
df_baqueira
# Out:
#    id            name  downhill_skiing  nordic_skiing opening_date  \
# 0  16  Baqueira Beret                1              0   26/11/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs special_runs_text  \
# 0  2023-01-19 08:52:22  ...               17            1       Itinerarios
#
#   special_runs_open special_runs_total avalanche_risk avalanche_risk_text  \
# 0                 -                  3              3             Notable
#
#                                    extended_elements comment snowpark
# 0  [{'group_name': 'Actividades', 'group_items': ...     NaN        1
#
# [1 rows x 39 columns]

# %%
df = pd.concat([df,df_baqueira])

# %%
bo = pd.DataFrame(boi_taull)
boi = pd.DataFrame(boi_taull['snowreports'])

df_boitaull = bo.join(boi, how='left')

# %%
df_boitaull.insert(34, 'snowpark', 1)

# %%
df_boitaull
# Out:
#    id       name  downhill_skiing  nordic_skiing opening_date  \
# 0  17  Boí Taüll                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... blue_runs_total red_runs_open red_runs_total  \
# 0  2023-01-19 08:52:22  ...               6             7             15
#
#   black_runs_open black_runs_total special_runs avalanche_risk  \
# 0               6               16            0             -1
#
#   avalanche_risk_text                                  extended_elements  \
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
#
#   snowpark
# 0        1
#
# [1 rows x 35 columns]

# %%
df = pd.concat([df,df_boitaull])

# %%
df
# Out:
#       id            name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001        Alp 2500                1              0   02/12/2022
# 0     20       La Molina                1              0   03/12/2022
# 0     19         Masella                1              0   02/12/2022
# 0     16  Baqueira Beret                1              0   26/11/2022
# 0     17       Boí Taüll                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
#
#   comment snowpark special_runs_text special_runs_open special_runs_total
# 0     NaN        0               NaN               NaN                NaN
# 0     NaN        1               NaN               NaN                NaN
# 0     NaN        0               NaN               NaN                NaN
# 0     NaN        1       Itinerarios                 -                  3
# 0     NaN        1               NaN               NaN                NaN
#
# [5 rows x 39 columns]

# %%
esp = pd.DataFrame(espot)
espo = pd.DataFrame(espot['snowreports'])

df_espot = esp.join(espo, how='left')

# %%
df_espot
# Out:
#    id   name  downhill_skiing  nordic_skiing opening_date  opening_confirmed  \
# 0  18  Espot                1              0   02/12/2022                  1
#
#   closing_date                                        snowreports        date  \
# 0   31/03/2023  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... blue_runs_open blue_runs_total red_runs_open  \
# 0  2023-01-19 09:17:53  ...              4              10             3
#
#   red_runs_total black_runs_open black_runs_total special_runs avalanche_risk  \
# 0              6               1                4            0              5
#
#   avalanche_risk_text                                  extended_elements
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
#
# [1 rows x 34 columns]

# %%
df_espot.insert(34, 'snowpark', 0)

# %%
df = pd.concat([df,df_espot])

# %%
df
# Out:
#       id            name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001        Alp 2500                1              0   02/12/2022
# 0     20       La Molina                1              0   03/12/2022
# 0     19         Masella                1              0   02/12/2022
# 0     16  Baqueira Beret                1              0   26/11/2022
# 0     17       Boí Taüll                1              0   02/12/2022
# 0     18           Espot                1              0   02/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   31/03/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
# 0  2023-01-19 09:17:53  ...                4            0              5
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
#
#   comment snowpark special_runs_text special_runs_open special_runs_total
# 0     NaN        0               NaN               NaN                NaN
# 0     NaN        1               NaN               NaN                NaN
# 0     NaN        0               NaN               NaN                NaN
# 0     NaN        1       Itinerarios                 -                  3
# 0     NaN        1               NaN               NaN                NaN
# 0     NaN        0               NaN               NaN                NaN
#
# [6 rows x 39 columns]

# %%
por = pd.DataFrame(port_aine)

port = pd.DataFrame(port_aine['snowreports'])

# %%
port_aine['snowreports'][0]['extended_elements']
# Out:
# [{'group_name': 'Actividades',
#   'group_items': [{'element_name': 'Snowpark',
#     'element_status_id': '0',
#     'element_status_text': 'Cerrado',
#     'element_icon': 30},
#    {'element_name': 'Itinerarios de Skimo',
#     'element_status_id': '1',
#     'element_status_text': 'Abierto',
#     'element_icon': 67,
#     'element_num_open': '4',
#     'element_num_total': '4',
#     'element_num_text': 'itinerarios',
#     'element_km_open': '9.66',
#     'element_km_total': '9.66'},
#    {'element_name': 'Raquetas',
#     'element_status_id': '1',
#     'element_status_text': 'Abierto',
#     'element_icon': 33,
#     'element_num_open': '2',
#     'element_num_total': '3',
#     'element_num_text': 'itinerarios',
#     'element_km_open': '8.64',
#     'element_km_total': '18.01'},
#    {'element_name': 'Trineos',
#     'element_status_id': '1',
#     'element_status_text': 'Abierto',
#     'element_icon': 32}]}]

# %%
df_portaine = por.join(port, how='left')

# %%
df_portaine.drop_duplicates(subset='name', inplace=True)

# %%
df_portaine.insert(35, 'snowpark', 1)

# %%
df = pd.concat([df,df_portaine])

# %%
por = pd.DataFrame(port_del_comte)
port = pd.DataFrame(port_del_comte['snowreports'])

df_port = por.join(port, how='left')

# %%
df_port.insert(34, 'snowpark', 0)

# %%
df = pd.concat([df, df_port])

# %%
df
# Out:
#       id            name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001        Alp 2500                1              0   02/12/2022
# 0     20       La Molina                1              0   03/12/2022
# 0     19         Masella                1              0   02/12/2022
# 0     16  Baqueira Beret                1              0   26/11/2022
# 0     17       Boí Taüll                1              0   02/12/2022
# 0     18           Espot                1              0   02/12/2022
# 0     21       Port Ainé                1              0   02/12/2022
# 0     22  Port del Comte                1              0   03/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   31/03/2023
# 0                  1   10/04/2023
# 0                  1   10/03/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
# 0  2023-01-19 09:17:53  ...                4            0              5
# 0  2023-01-19 08:52:22  ...                4            0              2
# 0  2023-01-19 08:52:22  ...                6            0             -1
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
# 0            Limitado  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Sectores', 'group_items': [{'...
#
#   comment snowpark special_runs_text special_runs_open special_runs_total
# 0     NaN        0               NaN               NaN                NaN
# 0     NaN        1               NaN               NaN                NaN
# 0     NaN        0               NaN               NaN                NaN
# 0     NaN        1       Itinerarios                 -                  3
# 0     NaN        1               NaN               NaN                NaN
# 0     NaN        0               NaN               NaN                NaN
# 0     NaN        1               NaN               NaN                NaN
# 0     NaN        0               NaN               NaN                NaN
#
# [8 rows x 39 columns]

# %%
tav = pd.DataFrame(tavascan)
tava = pd.DataFrame(tavascan['snowreports'])

df_tavascan = tav.join(tava, how='left')

# %%
df_tavascan.insert(34, 'snowpark', 0)

# %%
df = pd.concat([df,df_tavascan])

# %%
val = pd.DataFrame(vall_de_nuria)
vall = pd.DataFrame(vall_de_nuria['snowreports'])

df_vallde = val.join(vall, how='left')

# %%
df_vallde.drop_duplicates(subset='name')
# Out:
#    id           name  downhill_skiing  nordic_skiing opening_date  \
# 0  23  Vall de Nuria                1              0   03/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   09/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... blue_runs_total red_runs_open red_runs_total  \
# 0  2023-01-19 09:17:53  ...               3             -              3
#
#   black_runs_open black_runs_total special_runs avalanche_risk  \
# 0               -                2            0              0
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
#
#   comment
# 0     NaN
#
# [1 rows x 35 columns]

# %%
df_vallde.insert(35, 'snowpark', 0)

# %%
df = pd.concat([df,df_vallde])

# %%
df
# Out:
#       id            name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001        Alp 2500                1              0   02/12/2022
# 0     20       La Molina                1              0   03/12/2022
# 0     19         Masella                1              0   02/12/2022
# 0     16  Baqueira Beret                1              0   26/11/2022
# 0     17       Boí Taüll                1              0   02/12/2022
# 0     18           Espot                1              0   02/12/2022
# 0     21       Port Ainé                1              0   02/12/2022
# 0     22  Port del Comte                1              0   03/12/2022
# 0   2412        Tavascán                1              0   07/12/2022
# 0     23   Vall de Nuria                1              0   03/12/2022
# 1     23   Vall de Nuria                1              0   03/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   31/03/2023
# 0                  1   10/04/2023
# 0                  1   10/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 1                  1   09/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 1  {'date': '2023-01-20', 'updated': '2023-01-20 ...  2023-01-20
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
# 0  2023-01-19 09:17:53  ...                4            0              5
# 0  2023-01-19 08:52:22  ...                4            0              2
# 0  2023-01-19 08:52:22  ...                6            0             -1
# 0  2023-01-19 08:52:22  ...                2            0              3
# 0  2023-01-19 09:17:53  ...                2            0              0
# 1  2023-01-20 08:49:02  ...                2            0              0
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
# 0            Limitado  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Sectores', 'group_items': [{'...
# 0             Notable                                                NaN
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 1          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
#
#                                              comment snowpark  \
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0  Pistas de esquí cerradas. Previsión de reapert...        0
# 0                                                NaN        0
# 1  Apertura parcial debida a condiciones meteorol...        0
#
#   special_runs_text special_runs_open special_runs_total
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                  3
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
#
# [11 rows x 39 columns]

# %%
vallter0 = pd.DataFrame(vallter)
vallter1 = pd.DataFrame(vallter['snowreports'])

df_vallter = vallter0.join(vallter1, how='left')

# %%
df_vallter.insert(34, 'snowpark', 0)

# %%
df = pd.concat([df,df_vallter])

# %%
df
# Out:
#       id            name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001        Alp 2500                1              0   02/12/2022
# 0     20       La Molina                1              0   03/12/2022
# 0     19         Masella                1              0   02/12/2022
# 0     16  Baqueira Beret                1              0   26/11/2022
# 0     17       Boí Taüll                1              0   02/12/2022
# 0     18           Espot                1              0   02/12/2022
# 0     21       Port Ainé                1              0   02/12/2022
# 0     22  Port del Comte                1              0   03/12/2022
# 0   2412        Tavascán                1              0   07/12/2022
# 0     23   Vall de Nuria                1              0   03/12/2022
# 1     23   Vall de Nuria                1              0   03/12/2022
# 0     24         Vallter                1              0   04/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   31/03/2023
# 0                  1   10/04/2023
# 0                  1   10/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 1                  1   09/04/2023
# 0                  1   22/03/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 1  {'date': '2023-01-20', 'updated': '2023-01-20 ...  2023-01-20
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
# 0  2023-01-19 09:17:53  ...                4            0              5
# 0  2023-01-19 08:52:22  ...                4            0              2
# 0  2023-01-19 08:52:22  ...                6            0             -1
# 0  2023-01-19 08:52:22  ...                2            0              3
# 0  2023-01-19 09:17:53  ...                2            0              0
# 1  2023-01-20 08:49:02  ...                2            0              0
# 0  2023-01-19 09:17:53  ...                -            0              0
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
# 0            Limitado  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Sectores', 'group_items': [{'...
# 0             Notable                                                NaN
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 1          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
#
#                                              comment snowpark  \
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0  Pistas de esquí cerradas. Previsión de reapert...        0
# 0                                                NaN        0
# 1  Apertura parcial debida a condiciones meteorol...        0
# 0                                                NaN        0
#
#   special_runs_text special_runs_open special_runs_total
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                  3
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 0               NaN               NaN                NaN
#
# [12 rows x 39 columns]

# %%
df.drop_duplicates(subset='name')
# Out:
#       id            name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001        Alp 2500                1              0   02/12/2022
# 0     20       La Molina                1              0   03/12/2022
# 0     19         Masella                1              0   02/12/2022
# 0     16  Baqueira Beret                1              0   26/11/2022
# 0     17       Boí Taüll                1              0   02/12/2022
# 0     18           Espot                1              0   02/12/2022
# 0     21       Port Ainé                1              0   02/12/2022
# 0     22  Port del Comte                1              0   03/12/2022
# 0   2412        Tavascán                1              0   07/12/2022
# 0     23   Vall de Nuria                1              0   03/12/2022
# 0     24         Vallter                1              0   04/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   31/03/2023
# 0                  1   10/04/2023
# 0                  1   10/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 0                  1   22/03/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
# 0  2023-01-19 09:17:53  ...                4            0              5
# 0  2023-01-19 08:52:22  ...                4            0              2
# 0  2023-01-19 08:52:22  ...                6            0             -1
# 0  2023-01-19 08:52:22  ...                2            0              3
# 0  2023-01-19 09:17:53  ...                2            0              0
# 0  2023-01-19 09:17:53  ...                -            0              0
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
# 0            Limitado  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Sectores', 'group_items': [{'...
# 0             Notable                                                NaN
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
#
#                                              comment snowpark  \
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0  Pistas de esquí cerradas. Previsión de reapert...        0
# 0                                                NaN        0
# 0                                                NaN        0
#
#   special_runs_text special_runs_open special_runs_total
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                  3
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
#
# [11 rows x 39 columns]

# %%
astun_ = pd.DataFrame(astun_candanchu)
astuncan = pd.DataFrame(astun_candanchu['snowreports'])

df_ascan = astun_.join(astuncan,how='left')

# %%
df_ascan.insert(34, 'snowpark', 0)

# %%
df = pd.concat([df,df_ascan])

# %%
a =pd.DataFrame(astun)
ast = pd.DataFrame(astun['snowreports'])

df_astun = a.join(ast, how='left')

# %%
df_astun.insert(34, 'snowpark', 1)

# %%
df = pd.concat([df,df_astun])

# %%
can = pd.DataFrame(candanchu)
candan = pd.DataFrame(candanchu['snowreports'])

df_can = can.join(candan, how='left')

# %%
df_can.insert(34, 'snowpark', 0)

# %%
df = pd.concat([df,df_can])

# %%
df
# Out:
#       id                    name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001                Alp 2500                1              0   02/12/2022
# 0     20               La Molina                1              0   03/12/2022
# 0     19                 Masella                1              0   02/12/2022
# 0     16          Baqueira Beret                1              0   26/11/2022
# 0     17               Boí Taüll                1              0   02/12/2022
# 0     18                   Espot                1              0   02/12/2022
# 0     21               Port Ainé                1              0   02/12/2022
# 0     22          Port del Comte                1              0   03/12/2022
# 0   2412                Tavascán                1              0   07/12/2022
# 0     23           Vall de Nuria                1              0   03/12/2022
# 1     23           Vall de Nuria                1              0   03/12/2022
# 0     24                 Vallter                1              0   04/12/2022
# 0  22003  100K Astún - Candanchú                1              0   03/12/2022
# 0      7                   Astún                1              0   03/12/2022
# 0      8               Candanchú                1              0   03/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   31/03/2023
# 0                  1   10/04/2023
# 0                  1   10/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 1                  1   09/04/2023
# 0                  1   22/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 1  {'date': '2023-01-20', 'updated': '2023-01-20 ...  2023-01-20
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
# 0  2023-01-19 09:17:53  ...                4            0              5
# 0  2023-01-19 08:52:22  ...                4            0              2
# 0  2023-01-19 08:52:22  ...                6            0             -1
# 0  2023-01-19 08:52:22  ...                2            0              3
# 0  2023-01-19 09:17:53  ...                2            0              0
# 1  2023-01-20 08:49:02  ...                2            0              0
# 0  2023-01-19 09:17:53  ...                -            0              0
# 0  2023-01-19 08:52:22  ...               19            1              3
# 0  2023-01-19 08:52:22  ...                6            1              3
# 0  2023-01-19 08:52:22  ...               13            0              3
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
# 0            Limitado  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Sectores', 'group_items': [{'...
# 0             Notable                                                NaN
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 1          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable                                                NaN
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
#
#                                              comment snowpark  \
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0  Pistas de esquí cerradas. Previsión de reapert...        0
# 0                                                NaN        0
# 1  Apertura parcial debida a condiciones meteorol...        0
# 0                                                NaN        0
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
#
#   special_runs_text special_runs_open special_runs_total
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                  3
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                 10
# 0       Itinerarios                 -                 10
# 0               NaN               NaN                NaN
#
# [15 rows x 39 columns]

# %%
cer = pd.DataFrame(cerler)
cerl = pd.DataFrame(cerler['snowreports'])

df_cerler = cer.join(cerl, how='left')

# %%
df_cerler.insert(35, 'snowpark', 1)

# %%
df = pd.concat([df, df_cerler])

# %%
df
# Out:
#       id                    name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001                Alp 2500                1              0   02/12/2022
# 0     20               La Molina                1              0   03/12/2022
# 0     19                 Masella                1              0   02/12/2022
# 0     16          Baqueira Beret                1              0   26/11/2022
# 0     17               Boí Taüll                1              0   02/12/2022
# 0     18                   Espot                1              0   02/12/2022
# 0     21               Port Ainé                1              0   02/12/2022
# 0     22          Port del Comte                1              0   03/12/2022
# 0   2412                Tavascán                1              0   07/12/2022
# 0     23           Vall de Nuria                1              0   03/12/2022
# 1     23           Vall de Nuria                1              0   03/12/2022
# 0     24                 Vallter                1              0   04/12/2022
# 0  22003  100K Astún - Candanchú                1              0   03/12/2022
# 0      7                   Astún                1              0   03/12/2022
# 0      8               Candanchú                1              0   03/12/2022
# 0      9                  Cerler                1              0   06/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   31/03/2023
# 0                  1   10/04/2023
# 0                  1   10/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 1                  1   09/04/2023
# 0                  1   22/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 1  {'date': '2023-01-20', 'updated': '2023-01-20 ...  2023-01-20
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
# 0  2023-01-19 09:17:53  ...                4            0              5
# 0  2023-01-19 08:52:22  ...                4            0              2
# 0  2023-01-19 08:52:22  ...                6            0             -1
# 0  2023-01-19 08:52:22  ...                2            0              3
# 0  2023-01-19 09:17:53  ...                2            0              0
# 1  2023-01-20 08:49:02  ...                2            0              0
# 0  2023-01-19 09:17:53  ...                -            0              0
# 0  2023-01-19 08:52:22  ...               19            1              3
# 0  2023-01-19 08:52:22  ...                6            1              3
# 0  2023-01-19 08:52:22  ...               13            0              3
# 0  2023-01-19 08:52:22  ...               16            1              3
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
# 0            Limitado  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Sectores', 'group_items': [{'...
# 0             Notable                                                NaN
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 1          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable                                                NaN
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
#
#                                              comment snowpark  \
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0  Pistas de esquí cerradas. Previsión de reapert...        0
# 0                                                NaN        0
# 1  Apertura parcial debida a condiciones meteorol...        0
# 0                                                NaN        0
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0  Apertura parcial debida a condiciones meteorol...        1
#
#   special_runs_text special_runs_open special_runs_total
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                  3
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                 10
# 0       Itinerarios                 -                 10
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                  1
#
# [16 rows x 39 columns]

# %%
f_ = pd.DataFrame(formigal_panticosa)
f_p = pd.DataFrame(formigal_panticosa['snowreports'])

df_fp = f_.join(f_p, how='left')

# %%
df_fp.insert(34, 'snowpark', 0)

# %%
df = pd.concat([df,df_fp])

# %%
df
# Out:
#       id                    name  downhill_skiing  nordic_skiing opening_date  \
# 0  22001                Alp 2500                1              0   02/12/2022
# 0     20               La Molina                1              0   03/12/2022
# 0     19                 Masella                1              0   02/12/2022
# 0     16          Baqueira Beret                1              0   26/11/2022
# 0     17               Boí Taüll                1              0   02/12/2022
# 0     18                   Espot                1              0   02/12/2022
# 0     21               Port Ainé                1              0   02/12/2022
# 0     22          Port del Comte                1              0   03/12/2022
# 0   2412                Tavascán                1              0   07/12/2022
# 0     23           Vall de Nuria                1              0   03/12/2022
# 1     23           Vall de Nuria                1              0   03/12/2022
# 0     24                 Vallter                1              0   04/12/2022
# 0  22003  100K Astún - Candanchú                1              0   03/12/2022
# 0      7                   Astún                1              0   03/12/2022
# 0      8               Candanchú                1              0   03/12/2022
# 0      9                  Cerler                1              0   06/12/2022
# 0  22002    Formigal - Panticosa                1              0   03/12/2022
#
#    opening_confirmed closing_date  \
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   10/04/2023
# 0                  1   31/03/2023
# 0                  1   10/04/2023
# 0                  1   10/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 1                  1   09/04/2023
# 0                  1   22/03/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
# 0                  1   09/04/2023
#
#                                          snowreports        date  \
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 1  {'date': '2023-01-20', 'updated': '2023-01-20 ...  2023-01-20
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
# 0  {'date': '2023-01-19', 'updated': '2023-01-19 ...  2023-01-19
#
#                updated  ... black_runs_total special_runs avalanche_risk  \
# 0  2023-01-19 08:52:22  ...               16            0              0
# 0  2023-01-19 09:17:53  ...                6            0              0
# 0  2023-01-19 08:52:22  ...               10            0             -1
# 0  2023-01-19 08:52:22  ...               17            1              3
# 0  2023-01-19 08:52:22  ...               16            0             -1
# 0  2023-01-19 09:17:53  ...                4            0              5
# 0  2023-01-19 08:52:22  ...                4            0              2
# 0  2023-01-19 08:52:22  ...                6            0             -1
# 0  2023-01-19 08:52:22  ...                2            0              3
# 0  2023-01-19 09:17:53  ...                2            0              0
# 1  2023-01-20 08:49:02  ...                2            0              0
# 0  2023-01-19 09:17:53  ...                -            0              0
# 0  2023-01-19 08:52:22  ...               19            1              3
# 0  2023-01-19 08:52:22  ...                6            1              3
# 0  2023-01-19 08:52:22  ...               13            0              3
# 0  2023-01-19 08:52:22  ...               16            1              3
# 0  2023-01-19 08:52:22  ...               42            1              3
#
#   avalanche_risk_text                                  extended_elements  \
# 0          Sin Riesgo  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Dominio', 'group_items': [{'e...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Actividades', 'group_items': ...
# 0             Extremo  [{'group_name': 'Actividades', 'group_items': ...
# 0            Limitado  [{'group_name': 'Actividades', 'group_items': ...
# 0     sin información  [{'group_name': 'Sectores', 'group_items': [{'...
# 0             Notable                                                NaN
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 1          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0          Sin Riesgo  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable                                                NaN
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable  [{'group_name': 'Actividades', 'group_items': ...
# 0             Notable                                                NaN
#
#                                              comment snowpark  \
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        1
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0  Pistas de esquí cerradas. Previsión de reapert...        0
# 0                                                NaN        0
# 1  Apertura parcial debida a condiciones meteorol...        0
# 0                                                NaN        0
# 0                                                NaN        0
# 0                                                NaN        1
# 0                                                NaN        0
# 0  Apertura parcial debida a condiciones meteorol...        1
# 0  Previsión de condiciones meteorológicas advers...        0
#
#   special_runs_text special_runs_open special_runs_total
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                  3
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                 10
# 0       Itinerarios                 -                 10
# 0               NaN               NaN                NaN
# 0       Itinerarios                 -                  1
# 0       Itinerarios                 -                  5
#
# [17 rows x 39 columns]
